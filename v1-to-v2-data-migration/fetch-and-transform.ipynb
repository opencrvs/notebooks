// %%
// Define default values
const DEFAULT_RECORD_ID = '5f908740-9a5e-4e51-9fea-59c29374b1b9'// 'e68a3b3b-e7f0-42d4-9035-313dca4df0f0';

// Support command line arguments when running as a script
const RECORD_ID = Deno?.args?.[0] || DEFAULT_RECORD_ID;
const domain = Deno?.args?.[1] || 'localhost';
const GATEWAY = `http://${domain.includes('localhost') ? `${domain}:7070` : `gateway.${domain}`}`;
const REGISTER_APP = `http://${domain.includes('localhost') ? `${domain}:3000` : `register.${domain}`}`;

// %%
import { authenticate } from './authentication.ts';
const token = await authenticate(GATEWAY, 'k.mweene', 'test');
token
// Out:
// "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....rk0qighHKjClSq_ra-eo4oBxmC3ZTNgRPl_ZOOChRGsNvjGtWp9dnRBQG2nYnvp2Tq3R-JvOqMcFU6wGxLkFiLYRTI5oJQFwpAL2DKlTyO2o76TYdGnxmB11rWWGSxD7x_OFNJKIY2mtQ6bj5Prtrzs1MJoamrQnC0y4Og7hi4aicf18xD1rRpo1dIGuYQ3skQ7bsGkaalzjORrX_Yt3vgG600m1RWOtS2Sjorrmk1aSV3BWLXDmhhg8T5M16AWkHwpHnJNkjFXpING4CfMmEm753ACF5ubAbtvOFiJD7ryRrnROucKUAveXZI1PLK9fmc-9w5rgGxFziRTvstZvVw"

// %%
const fetchBirthRegistration = async () => {
  const response = await fetch(`${GATEWAY}/graphql`, {
    method: "POST",
    headers: {
      "Content-Type": "application/json",
      Authorization: `Bearer ${token}`,
    },
    body: JSON.stringify({
      operationName: "fetchBirthRegistration",
      variables: {
        id: RECORD_ID,
      },
      query: `query fetchBirthRegistration($id: ID!) {
  fetchBirthRegistration(id: $id) {
    _fhirIDMap
    id
    child {
      id
      identifier {
        id
        type
        otherType
        __typename
      }
      name {
        use
        firstNames
        middleName
        familyName
        __typename
      }
      birthDate
      gender
      __typename
    }
    informant {
      id
      relationship
      otherRelationship
      _fhirIDPatient
      identifier {
        id
        type
        otherType
        fieldsModifiedByIdentity
        __typename
      }
      name {
        use
        firstNames
        middleName
        familyName
        __typename
      }
      occupation
      nationality
      birthDate
      ageOfIndividualInYears
      exactDateOfBirthUnknown
      address {
        type
        line
        district
        state
        city
        postalCode
        country
        __typename
      }
      __typename
    }
    mother {
      id
      name {
        use
        firstNames
        middleName
        familyName
        __typename
      }
      multipleBirth
      birthDate
      maritalStatus
      occupation
      detailsExist
      reasonNotApplying
      ageOfIndividualInYears
      exactDateOfBirthUnknown
      dateOfMarriage
      educationalAttainment
      nationality
      identifier {
        id
        type
        otherType
        fieldsModifiedByIdentity
        __typename
      }
      address {
        type
        line
        district
        state
        city
        postalCode
        country
        __typename
      }
      telecom {
        system
        value
        __typename
      }
      __typename
    }
    father {
      id
      name {
        use
        firstNames
        middleName
        familyName
        __typename
      }
      birthDate
      maritalStatus
      occupation
      detailsExist
      reasonNotApplying
      ageOfIndividualInYears
      exactDateOfBirthUnknown
      dateOfMarriage
      educationalAttainment
      nationality
      identifier {
        id
        type
        otherType
        fieldsModifiedByIdentity
        __typename
      }
      address {
        type
        line
        district
        state
        city
        postalCode
        country
        __typename
      }
      telecom {
        system
        value
        __typename
      }
      __typename
    }
    registration {
      id
      informantType
      otherInformantType
      contact
      contactRelationship
      contactPhoneNumber
      contactEmail
      assignment {
        practitionerId
        firstName
        lastName
        officeName
        avatarURL
        __typename
      }
      certificates {
        hasShowedVerifiedDocument
        certificateTemplateId
        collector {
          relationship
          otherRelationship
          name {
            use
            firstNames
            familyName
            __typename
          }
          telecom {
            system
            value
            use
            __typename
          }
          __typename
        }
        __typename
      }
      duplicates {
        compositionId
        trackingId
        __typename
      }
      informantsSignature
      attachments {
        data
        uri
        type
        contentType
        subject
        __typename
      }
      status {
        comments {
          comment
          __typename
        }
        type
        timestamp
        office {
          name
          alias
          address {
            district
            state
            __typename
          }
          partOf
          __typename
        }
        __typename
      }
      type
      trackingId
      registrationNumber
      __typename
    }
    attendantAtBirth
    weightAtBirth
    birthType
    eventLocation {
      id
      type
      address {
        line
        district
        state
        city
        postalCode
        country
        __typename
      }
      __typename
    }
    questionnaire {
      fieldId
      value
      __typename
    }
    history {
      otherReason
      requester
      requesterOther
      noSupportingDocumentationRequired
      hasShowedVerifiedDocument
      certificateTemplateId
      date
      action
      regStatus
      dhis2Notification
      ipAddress
      documents {
        id
        data
        uri
        type
        __typename
      }
      payment {
        id
        type
        amount
        outcome
        date
        attachmentURL
        __typename
      }
      statusReason {
        text
        __typename
      }
      reason
      location {
        id
        name
        __typename
      }
      office {
        id
        name
        alias
        address {
          state
          district
          __typename
        }
        __typename
      }
      system {
        name
        type
        __typename
      }
      user {
        id
        role {
          id
          label {
            id
            defaultMessage
            description
            __typename
          }
          __typename
        }
        primaryOffice {
          id
          __typename
        }
        name {
          firstNames
          familyName
          use
          __typename
        }
        avatar {
          data
          type
          __typename
        }
        __typename
      }
      signature {
        data
        type
        __typename
      }
      comments {
        user {
          id
          username
          avatar {
            data
            type
            __typename
          }
          __typename
        }
        comment
        createdAt
        __typename
      }
      input {
        valueCode
        valueId
        value
        __typename
      }
      output {
        valueCode
        valueId
        value
        __typename
      }
      certificates {
        hasShowedVerifiedDocument
        certificateTemplateId
        collector {
          relationship
          otherRelationship
          name {
            use
            firstNames
            familyName
            __typename
          }
          telecom {
            system
            value
            use
            __typename
          }
          __typename
        }
        certifier {
          name {
            use
            firstNames
            familyName
            __typename
          }
          role {
            id
            label {
              id
              defaultMessage
              description
              __typename
            }
            __typename
          }
          __typename
        }
        __typename
      }
      duplicateOf
      potentialDuplicates
      __typename
    }
    __typename
  }
}
`,
    }),
  });

  if (!response.ok) {
    throw new Error(`GraphQL request failed: ${response.statusText}`);
  }
  return response.json();
};

// Example usage:
const birthRegistrationData = await fetchBirthRegistration();

// %%
import { v4 as uuidv4 } from 'npm:uuid';

const createBirthEvent = async () => {
  const transactionId = `tmp-${uuidv4()}`;
  const payload = {
    json: {
      type: "v2.birth",
      transactionId,
      declaration: null
    },
    meta: {
      values: {
        declaration: ["undefined"]
      }
    }
  };

  const response = await fetch(`${GATEWAY}/events/event.create`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json', Authorization: `Bearer ${token}` },
    body: JSON.stringify(payload)
  });

  if (!response.ok) {
    throw new Error(`Event creation failed: ${response.statusText}`);
  }
  return response.json();
};

// Example usage:
const eventResponse = await createBirthEvent();
const eventId = eventResponse.result.data.json.id

// %%
const authenticateJCampbell = async () => {
  const response = await fetch(`${GATEWAY}/auth/authenticate`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json' },
    body: JSON.stringify({ username: 'j.campbell', password: 'test' })
  });
  if (!response.ok) {
    throw new Error(`Authentication failed: ${response.statusText}`);
  }
  return response.json();
};

const nonceJCampbell = (await authenticateJCampbell()).nonce;

const verifyCodeJCampbell = async (code: string, nonce: string) => {
  const response = await fetch(`${GATEWAY}/auth/verifyCode`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json' },
    body: JSON.stringify({ code, nonce })
  });
  if (!response.ok) {
    throw new Error(`Code verification failed: ${response.statusText}`);
  }
  return response.json();
};

const tokenJCampbell = (await verifyCodeJCampbell('000000', nonceJCampbell)).token;

// %%
const registerSystem = async () => {
  const response = await fetch(`${GATEWAY}/graphql`, {
    method: "POST",
    headers: {
      "Content-Type": "application/json",
      Authorization: `Bearer ${tokenJCampbell}`,
    },
    body: JSON.stringify({
      operationName: "registerSystem",
      variables: {
        system: {
          type: "IMPORT",
          name: "Import"
        }
      },
      query: `mutation registerSystem($system: SystemInput) {
        registerSystem(system: $system) {
          clientSecret
          system {
            _id
            clientId
            name
            shaSecret
            status
            type
            integratingSystemType
            settings {
              webhook {
                event
                permissions
                __typename
              }
              __typename
            }
            __typename
          }
          __typename
        }
      }`
    }),
  });

  if (!response.ok) {
    throw new Error(`GraphQL request failed: ${response.statusText}`);
  }
  return response.json();
};

// Example usage:
const systemRegistration = await registerSystem();
const clientId = systemRegistration.data.registerSystem.system.clientId;
const clientSecret = systemRegistration.data.registerSystem.clientSecret;

// %%
async function getTokenForSystemClient(
  clientId: string,
  clientSecret: string
): Promise<string> {
  const authenticateResponse = await fetch(
    `${GATEWAY}/auth/token?client_id=${clientId}&client_secret=${clientSecret}&grant_type=client_credentials`,
    {
      method: 'POST',
      headers: {
        'Content-Type': 'application/json',
        'x-correlation-id': clientId + '-' + Date.now()
      }
    }
  );
  const res = await authenticateResponse.json();

  return res.token || res.access_token;
}

// %%
birthRegistrationData.data.fetchBirthRegistration
// Out:
// {
//   _fhirIDMap: {
//     composition: "5f908740-9a5e-4e51-9fea-59c29374b1b9",
//     encounter: "0d06f43b-97b6-4cf8-96f5-7e8548bb2c3f",
//     eventLocation: "5fca1429-0ea9-43d0-981f-4ee54faaee81",
//     observation: {
//       birthType: "72b47b61-382e-479e-9845-783b09cf34df",
//       weightAtBirth: "919a3873-f8f3-4afd-9576-cc79f95d373a",
//       attendantAtBirth: "6c82c803-9ea6-4dc9-99b2-0a2f7a1f10e1"
//     },
//     questionnaireResponse: "a0d040bd-0241-4347-bbee-a4ad7d08b6d5"
//   },
//   id: "5f908740-9a5e-4e51-9fea-59c29374b1b9",
//   child: {
//     id: "80477670-de78-4eb8-84bd-e01829ebadb5",
//     identifier: [
//       {
//         id: "2025BRSN3TK",
//         type: "BIRTH_REGISTRATION_NUMBER",
//         otherType: null,
//         __typename: "IdentityType"
//       },
//       {
//         id: "",
//         type: "BIRTH_CONFIGURABLE_IDENTIFIER_1",
//         otherType: null,
//         __typename: "IdentityType"
//       },
//       {
//         id: "",
//         type: "BIRTH_CONFIGURABLE_IDENTIFIER_2",
//         otherType: null,
//         __typename: "IdentityType"
//       },
//       {
//         id: "",
//         type: "BIRTH_CONFIGURABLE_IDENTIFIER_3",
//         otherType: null,
//         __typename: "IdentityType"
//       }
//     ],
//     name: [
//       {
//         use: "en",
//         firstNames: "Euan ",
//         middleName: "",
//         familyName: "Millar",
//         __typename: "HumanName"
//       }
//     ],
//     birthDate: "2025-02-02",
//     gender: "male",
//     __typename: "Person"
//   },
//   informant: {
//     id: "a6f1bf67-429b-4d37-a512-64e599d76433",
//     relationship: "MOTHER",
//     otherRelationship: null,
//     _fhirIDPatient: "9d49f131-d03a-4450-8230-944f2eace9c8",
//     identifier: [
//       {
//         id: "6546546544",
//         type: "NATIONAL_ID",
//         otherType: null,
//         fieldsModifiedByIdentity: null,
//         __typename: "IdentityType"
//       }
//     ],
//     name: [
//       {
//         use: "en",
//         firstNames: "Sally",
//         middleName: "",
//         familyName: "Millar",
//         __typename: "HumanName"
//       }
//     ],
//     occupation: "Teacher",
//     nationality: [ "FAR" ],
//     birthDate: "1990-10-10",
//     ageOfIndividualInYears: null,
//     exactDateOfBirthUnknown: null,
//     address: [
//       {
//         type: "PRIMARY_ADDRESS",
//         line: [
//           "12",
//           "mother area",
//           "mother res area",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           ""
//         ],
//         district: "d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//         state: "ca8508b7-d97b-4fc4-bb57-d1c521ebecd4",
//         city: "Mother town",
//         postalCode: "765765",
//         country: "FAR",
//         __typename: "Address"
//       }
//     ],
//     __typename: "RelatedPerson"
//   },
//   mother: {
//     id: "9d49f131-d03a-4450-8230-944f2eace9c8",
//     name: [
//       {
//         use: "en",
//         firstNames: "Sally",
//         middleName: "",
//         familyName: "Millar",
//         __typename: "HumanName"
//       }
//     ],
//     multipleBirth: 2,
//     birthDate: "1990-10-10",
//     maritalStatus: "SINGLE",
//     occupation: "Teacher",
//     detailsExist: true,
//     reasonNotApplying: null,
//     ageOfIndividualInYears: null,
//     exactDateOfBirthUnknown: null,
//     dateOfMarriage: null,
//     educationalAttainment: "PRIMARY_ISCED_1",
//     nationality: [ "FAR" ],
//     identifier: [
//       {
//         id: "6546546544",
//         type: "NATIONAL_ID",
//         otherType: null,
//         fieldsModifiedByIdentity: null,
//         __typename: "IdentityType"
//       }
//     ],
//     address: [
//       {
//         type: "PRIMARY_ADDRESS",
//         line: [
//           "12",
//           "mother area",
//           "mother res area",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           "",
//           ""
//         ],
//         district: "d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//         state: "ca8508b7-d97b-4fc4-bb57-d1c521ebecd4",
//         city: "Mother town",
//         postalCode: "765765",
//         country: "FAR",
//         __typename: "Address"
//       }
//     ],
//     telecom: null,
//     __typename: "Person"
//   },
//   father: {
//     id: "9340fb58-2092-4a11-8451-4115b3ef9b36",
//     name: null,
//     birthDate: null,
//     maritalStatus: null,
//     occupation: null,
//     detailsExist: false,
//     reasonNotApplying: "absent",
//     ageOfIndividualInYears: null,
//     exactDateOfBirthUnknown: null,
//     dateOfMarriage: null,
//     educationalAttainment: null,
//     nationality: null,
//     identifier: null,
//     address: null,
//     telecom: null,
//     __typename: "Person"
//   },
//   registration: {
//     id: "17c73595-40e8-4508-a46c-3b77db3da83b",
//     informantType: "MOTHER",
//     otherInformantType: null,
//     contact: null,
//     contactRelationship: null,
//     contactPhoneNumber: "+260746546546",
//     contactEmail: "test@test.com",
//     assignment: {
//       practitionerId: "65b9ff64-4eda-4aff-b975-8adf22d5bf4f",
//       firstName: "Kennedy",
//       lastName: "Mweene",
//       officeName: "Ibombo District Office",
//       avatarURL: "https://eu.ui-avatars.com/api/?background=DEE5F2&color=222&name=Kennedy Mweene",
//       __typename: "AssignmentData"
//     },
//     certificates: [ null ],
//     duplicates: null,
//     informantsSignature: "http://localhost:3535/ocrvs/d1454dd2-2fac-454f-be6d-f001971053ea.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=minioadmin%2F20250604%2Flocal%2Fs3%2Faws4_request&X-Amz-Date=20250604T100658Z&X-Amz-Expires=259200&X-Amz-SignedHeaders=host&X-Amz-Signature=87866003943300ee0bcc4e1b8c32ae77e044f7466299ceb6365937f2d1b3d405",
//     attachments: [
//       {
//         data: "http://localhost:3535/ocrvs/3825d497-77b6-4734-8c92-599304dc8975.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=minioadmin%2F20250604%2Flocal%2Fs3%2Faws4_request&X-Amz-Date=20250604T100658Z&X-Amz-Expires=259200&X-Amz-SignedHeaders=host&X-Amz-Signature=f393fd60d3396c08760c0c6138402fc6e5cc6cb8a1205bd0c57618e20e8e8f11",
//         uri: "/ocrvs/3825d497-77b6-4734-8c92-599304dc8975.png",
//         type: "NOTIFICATION_OF_BIRTH",
//         contentType: "image/png",
//         subject: "CHILD",
//         __typename: "Attachment"
//       }
//     ],
//     status: [
//       {
//         comments: null,
//         type: "REGISTERED",
//         timestamp: "2025-06-04T10:06:58.710Z",
//         office: {
//           name: "Ibombo District Office",
//           alias: [Array],
//           address: null,
//           partOf: "Location/d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//           __typename: "Location"
//         },
//         __typename: "RegWorkflow"
//       },
//       {
//         comments: null,
//         type: "REGISTERED",
//         timestamp: "2025-06-03T11:22:26.832Z",
//         office: {
//           name: "Ibombo District Office",
//           alias: [Array],
//           address: null,
//           partOf: "Location/d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//           __typename: "Location"
//         },
//         __typename: "RegWorkflow"
//       },
//       {
//         comments: null,
//         type: "WAITING_VALIDATION",
//         timestamp: "2025-06-03T11:22:26.253Z",
//         office: {
//           name: "Ibombo District Office",
//           alias: [Array],
//           address: null,
//           partOf: "Location/d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//           __typename: "Location"
//         },
//         __typename: "RegWorkflow"
//       },
//       {
//         comments: null,
//         type: "DECLARED",
//         timestamp: "2025-06-03T11:22:25.953Z",
//         office: {
//           name: "Ibombo District Office",
//           alias: [Array],
//           address: null,
//           partOf: "Location/d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//           __typename: "Location"
//         },
//         __typename: "RegWorkflow"
//       }
//     ],
//     type: "BIRTH",
//     trackingId: "BRSN3TK",
//     registrationNumber: "2025BRSN3TK",
//     __typename: "Registration"
//   },
//   attendantAtBirth: "PHYSICIAN",
//   weightAtBirth: 4,
//   birthType: "SINGLE",
//   eventLocation: {
//     id: "5fca1429-0ea9-43d0-981f-4ee54faaee81",
//     type: "HEALTH_FACILITY",
//     address: null,
//     __typename: "Location"
//   },
//   questionnaire: [
//     {
//       fieldId: "birth.mother.mother-view-group.motherIdType",
//       value: "NATIONAL_ID",
//       __typename: "QuestionnaireQuestion"
//     }
//   ],
//   history: [
//     {
//       otherReason: "",
//       requester: "",
//       requesterOther: "",
//       noSupportingDocumentationRequired: false,
//       hasShowedVerifiedDocument: false,
//       certificateTemplateId: null,
//       date: "2025-06-04T10:06:58.710Z",
//       action: "ASSIGNED",
//       regStatus: "REGISTERED",
//       dhis2Notification: false,
//       ipAddress: null,
//       documents: [],
//       payment: null,
//       statusReason: null,
//       reason: null,
//       location: {
//         id: "d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//         name: "Ibombo",
//         __typename: "Location"
//       },
//       office: {
//         id: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//         name: "Ibombo District Office",
//         alias: [ "Ibombo District Office" ],
//         address: null,
//         __typename: "Location"
//       },
//       system: null,
//       user: {
//         id: "683ed9ff0ca183ce5a64c696",
//         role: {
//           id: "LOCAL_REGISTRAR",
//           label: [Object],
//           __typename: "UserRole"
//         },
//         primaryOffice: {
//           id: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//           __typename: "Location"
//         },
//         name: [ [Object] ],
//         avatar: null,
//         __typename: "User"
//       },
//       signature: null,
//       comments: [],
//       input: [],
//       output: [],
//       certificates: [ null ],
//       duplicateOf: null,
//       potentialDuplicates: null,
//       __typename: "History"
//     },
//     {
//       otherReason: "",
//       requester: "",
//       requesterOther: "",
//       noSupportingDocumentationRequired: false,
//       hasShowedVerifiedDocument: false,
//       certificateTemplateId: null,
//       date: "2025-06-03T11:22:26.871+00:00",
//       action: null,
//       regStatus: "REGISTERED",
//       dhis2Notification: false,
//       ipAddress: null,
//       documents: [],
//       payment: null,
//       statusReason: null,
//       reason: null,
//       location: {
//         id: "d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//         name: "Ibombo",
//         __typename: "Location"
//       },
//       office: {
//         id: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//         name: "Ibombo District Office",
//         alias: [ "Ibombo District Office" ],
//         address: null,
//         __typename: "Location"
//       },
//       system: null,
//       user: {
//         id: "683ed9ff0ca183ce5a64c696",
//         role: {
//           id: "LOCAL_REGISTRAR",
//           label: [Object],
//           __typename: "UserRole"
//         },
//         primaryOffice: {
//           id: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//           __typename: "Location"
//         },
//         name: [ [Object] ],
//         avatar: null,
//         __typename: "User"
//       },
//       signature: null,
//       comments: [],
//       input: [],
//       output: [],
//       certificates: [ null ],
//       duplicateOf: null,
//       potentialDuplicates: null,
//       __typename: "History"
//     },
//     {
//       otherReason: "",
//       requester: "",
//       requesterOther: "",
//       noSupportingDocumentationRequired: false,
//       hasShowedVerifiedDocument: false,
//       certificateTemplateId: null,
//       date: "2025-06-03T11:22:26.282+00:00",
//       action: null,
//       regStatus: "WAITING_VALIDATION",
//       dhis2Notification: false,
//       ipAddress: null,
//       documents: [],
//       payment: null,
//       statusReason: null,
//       reason: null,
//       location: {
//         id: "d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//         name: "Ibombo",
//         __typename: "Location"
//       },
//       office: {
//         id: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//         name: "Ibombo District Office",
//         alias: [ "Ibombo District Office" ],
//         address: null,
//         __typename: "Location"
//       },
//       system: null,
//       user: {
//         id: "683ed9ff0ca183ce5a64c696",
//         role: {
//           id: "LOCAL_REGISTRAR",
//           label: [Object],
//           __typename: "UserRole"
//         },
//         primaryOffice: {
//           id: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//           __typename: "Location"
//         },
//         name: [ [Object] ],
//         avatar: null,
//         __typename: "User"
//       },
//       signature: null,
//       comments: [],
//       input: [],
//       output: [],
//       certificates: [ null ],
//       duplicateOf: null,
//       potentialDuplicates: null,
//       __typename: "History"
//     },
//     {
//       otherReason: "",
//       requester: "",
//       requesterOther: "",
//       noSupportingDocumentationRequired: false,
//       hasShowedVerifiedDocument: false,
//       certificateTemplateId: null,
//       date: "2025-06-03T11:22:26.222+00:00",
//       action: null,
//       regStatus: "DECLARED",
//       dhis2Notification: false,
//       ipAddress: null,
//       documents: [],
//       payment: null,
//       statusReason: null,
//       reason: null,
//       location: {
//         id: "d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//         name: "Ibombo",
//         __typename: "Location"
//       },
//       office: {
//         id: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//         name: "Ibombo District Office",
//         alias: [ "Ibombo District Office" ],
//         address: null,
//         __typename: "Location"
//       },
//       system: null,
//       user: {
//         id: "683ed9ff0ca183ce5a64c696",
//         role: {
//           id: "LOCAL_REGISTRAR",
//           label: [Object],
//           __typename: "UserRole"
//         },
//         primaryOffice: {
//           id: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//           __typename: "Location"
//         },
//         name: [ [Object] ],
//         avatar: null,
//         __typename: "User"
//       },
//       signature: null,
//       comments: [],
//       input: [],
//       output: [],
//       certificates: [ null ],
//       duplicateOf: null,
//       potentialDuplicates: null,
//       __typename: "History"
//     }
//   ],
//   __typename: "BirthRegistration"
// }

// %%
import { transform } from './transform.ts'

const document = transform(birthRegistrationData.data.fetchBirthRegistration)
document
// Out:
// {
//   id: "5f908740-9a5e-4e51-9fea-59c29374b1b9",
//   type: "v2.birth",
//   createdAt: "2025-06-03T11:22:26.222Z",
//   updatedAt: "2025-06-03T11:22:26.871Z",
//   updatedAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//   trackingId: "BRSN3TK",
//   actions: [
//     {
//       type: "CREATE",
//       createdAt: "2025-06-03T11:22:26.222Z",
//       createdBy: "683ed9ff0ca183ce5a64c696",
//       createdByRole: "LOCAL_REGISTRAR",
//       createdAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//       updatedAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//       status: "Accepted",
//       declaration: {},
//       id: "cf9fc1ee-4b48-4e56-96fa-498b48431241",
//       transactionId: "68aa8369-1777-47fb-ad7f-a9b57160b411"
//     },
//     {
//       id: "29de88b2-af18-4d73-b060-57428844e583",
//       transactionId: "ac471bf3-2ff2-44b1-8b87-7df736fb124c",
//       createdAt: "2025-06-03T11:22:26.222Z",
//       createdBy: "683ed9ff0ca183ce5a64c696",
//       createdByRole: "LOCAL_REGISTRAR",
//       createdAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//       updatedAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//       status: "Accepted",
//       type: "DECLARE",
//       declaration: {
//         "child.firstname": "Euan ",
//         "child.middleName": "",
//         "child.surname": "Millar",
//         "child.gender": "male",
//         "child.dob": "2025-02-02",
//         "child.placeOfBirth": "HEALTH_FACILITY",
//         "child.birthLocation": "5fca1429-0ea9-43d0-981f-4ee54faaee81",
//         "child.attendantAtBirth": "PHYSICIAN",
//         "child.birthType": "SINGLE",
//         "child.weightAtBirth": 4,
//         "informant.dob": "1990-10-10",
//         "informant.address": {
//           addressType: "DOMESTIC",
//           urbanOrRural: "URBAN",
//           country: "FAR",
//           province: "ca8508b7-d97b-4fc4-bb57-d1c521ebecd4",
//           district: "d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//           town: "Mother town",
//           zipCode: "765765"
//         },
//         "informant.phoneNo": "0746546546",
//         "informant.email": "test@test.com",
//         "informant.relation": "MOTHER",
//         "informant.firstname": "Sally",
//         "informant.middleName": "",
//         "informant.surname": "Millar",
//         "informant.nationality": "FAR",
//         "mother.detailsNotAvailable": false,
//         "mother.firstname": "Sally",
//         "mother.surname": "Millar",
//         "mother.dob": "1990-10-10",
//         "mother.nationality": "FAR",
//         "mother.maritalStatus": "SINGLE",
//         "mother.educationalAttainment": "PRIMARY_ISCED_1",
//         "mother.occupation": "Teacher",
//         "mother.previousBirths": 2,
//         "mother.address": {
//           addressType: "DOMESTIC",
//           urbanOrRural: "URBAN",
//           country: "FAR",
//           province: "ca8508b7-d97b-4fc4-bb57-d1c521ebecd4",
//           district: "d47ae7af-b31c-48eb-a88a-8552a2fb8811",
//           town: "Mother town",
//           zipCode: "765765"
//         },
//         "mother.addressSameAs": [ [Object] ],
//         "father.detailsNotAvailable": true,
//         "father.reason": "absent",
//         "documents.proofOfBirth": {
//           filename: "3825d497-77b6-4734-8c92-599304dc8975.png",
//           originalFilename: "3825d497-77b6-4734-8c92-599304dc8975.png",
//           type: "image/png"
//         },
//         "informant.nid": "6546546544",
//         "mother.nid": "6546546544",
//         "mother.idType": "NATIONAL_ID"
//       },
//       annotation: {
//         "review.signature": "http://localhost:3535/ocrvs/d1454dd2-2fac-454f-be6d-f001971053ea.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=minioadmin%2F20250604%2Flocal%2Fs3%2Faws4_request&X-Amz-Date=20250604T100658Z&X-Amz-Expires=259200&X-Amz-SignedHeaders=host&X-Amz-Signature=87866003943300ee0bcc4e1b8c32ae77e044f7466299ceb6365937f2d1b3d405",
//         "review.comment": ""
//       }
//     },
//     {
//       id: "128737e7-5919-4ca3-9907-fe9fc497d90c",
//       transactionId: "f8df4f8a-15d4-4e6e-99ac-bc3ead195d40",
//       createdAt: "2025-06-03T11:22:26.282Z",
//       createdBy: "683ed9ff0ca183ce5a64c696",
//       createdByRole: "LOCAL_REGISTRAR",
//       createdAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//       updatedAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//       status: "Requested",
//       type: "REGISTER",
//       declaration: {}
//     },
//     {
//       id: "5016eaad-fde3-4ee9-b9c7-571490d9dd99",
//       transactionId: "0b25a0fb-167b-40ef-95a9-1361fa11f08f",
//       createdAt: "2025-06-03T11:22:26.871Z",
//       createdBy: "683ed9ff0ca183ce5a64c696",
//       createdByRole: "LOCAL_REGISTRAR",
//       createdAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//       updatedAtLocation: "8b0345f3-3a52-4277-a3a1-e0e09a5fbe3e",
//       status: "Accepted",
//       type: "REGISTER",
//       declaration: {},
//       registrationNumber: "2025BRSN3TK"
//     }
//   ]
// }

// %%
document

// %%
const sysToken = await getTokenForSystemClient(clientId, clientSecret);

const declareBirthEvent = async () => {
  const response = await fetch(`${GATEWAY}/events/event.import`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json', Authorization: `Bearer ${sysToken}` },
    body: JSON.stringify({json: document, meta: {
      values: {
        declaration: ["undefined"]
      }
    }})
  });

  if (!response.ok) {
    console.log((await response.json()).error.json.message);


    throw new Error(`Event creation failed: ${response.statusText}`);
  }
  return response.json();
};

const result = await declareBirthEvent()

// %%
console.log('🍞 Declaration with ID', RECORD_ID, 'was succesfully migrated!')
console.log()

console.log('You can view the original record', `[here](https://register.${domain}/${result.result.data.json.id}/viewRecord?V2_EVENTS=false)`)
console.log('and the new migrated record', `[here](https://register.${domain}/events/view/${result.result.data.json.id}?V2_EVENTS=true)`)
