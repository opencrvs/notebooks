// %%
// Define default values
const DEFAULT_RECORD_ID = 'e68a3b3b-e7f0-42d4-9035-313dca4df0f0';

// Support command line arguments when running as a script
const RECORD_ID = Deno?.args?.[0] || DEFAULT_RECORD_ID;
const domain = Deno?.args?.[1] || 'events-v2-test-environment.opencrvs.dev';
const GATEWAY = `http://${domain.includes('localhost') ? domain : `gateway.${domain}`}`;
// Out:
// Using RECORD_ID: e68a3b3b-e7f0-42d4-9035-313dca4df0f0
// Using GATEWAY: http://gateway.events-v2-test-environment.opencrvs.dev
// Using GATEWAY: http://gateway.events-v2-test-environment.opencrvs.dev

// %%
const authenticate = async (username: string, password: string) => {
  const response = await fetch(`${GATEWAY}/auth/authenticate`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json' },
    body: JSON.stringify({ username, password })
  });
  if (!response.ok) {
    throw new Error(`Authentication failed: ${response.statusText}`);
  }
  return response.json();
};

// Example usage:
const nonce = (await authenticate('k.mweene', 'test')).nonce
const verifyCode = async (code: string, nonce: string) => {
  const response = await fetch(`${GATEWAY}/auth/verifyCode`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json' },
    body: JSON.stringify({ code, nonce })
  });
  if (!response.ok) {
    throw new Error(`Code verification failed: ${response.statusText}`);
  }
  return response.json();
};


const token = (await verifyCode('000000', nonce)).token;
token
// Out:
// "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....jfgSMvteuLMdkPgGXNwGlaoOfuwkEpLi59FPPVqzoBYM-Bs0JcOcYsF9BJEmtly0MJXKAPoDPeIORwkuFnOlF5qfqA3x06nJDquSODhU8yZj8ZT683KnC7TMGq5FqtOK3EU0Ybsd27BeWa0n5tO9x5E-zJQ18BqrDj2oZVnYbAMu3eng7bQMUsXkdBI-3MyNc23XwKSWqORFBPscxxndX9Opa3IIrFEvbC9eNAKJQU7tTb6PvcPAzkxa98yA8J1gLl662Z57hGaC5daQ5vqW34abXBbuSni-SpmnmG0aMdjLO3pLpjepOs-FeqEJjASyiO-hrip9Z77yCVq_h3cZvg"

// %%
const fetchBirthRegistration = async () => {
  const response = await fetch(`${GATEWAY}/graphql`, {
    method: "POST",
    headers: {
      "Content-Type": "application/json",
      Authorization: `Bearer ${token}`,
    },
    body: JSON.stringify({
      operationName: "fetchBirthRegistration",
      variables: {
        id: RECORD_ID,
      },
      query: `query fetchBirthRegistration($id: ID!) {
  fetchBirthRegistration(id: $id) {
    _fhirIDMap
    id
    child {
      id
      identifier {
        id
        type
        otherType
        __typename
      }
      name {
        use
        firstNames
        middleName
        familyName
        __typename
      }
      birthDate
      gender
      __typename
    }
    informant {
      id
      relationship
      otherRelationship
      _fhirIDPatient
      identifier {
        id
        type
        otherType
        fieldsModifiedByIdentity
        __typename
      }
      name {
        use
        firstNames
        middleName
        familyName
        __typename
      }
      occupation
      nationality
      birthDate
      ageOfIndividualInYears
      exactDateOfBirthUnknown
      address {
        type
        line
        district
        state
        city
        postalCode
        country
        __typename
      }
      __typename
    }
    mother {
      id
      name {
        use
        firstNames
        middleName
        familyName
        __typename
      }
      multipleBirth
      birthDate
      maritalStatus
      occupation
      detailsExist
      reasonNotApplying
      ageOfIndividualInYears
      exactDateOfBirthUnknown
      dateOfMarriage
      educationalAttainment
      nationality
      identifier {
        id
        type
        otherType
        fieldsModifiedByIdentity
        __typename
      }
      address {
        type
        line
        district
        state
        city
        postalCode
        country
        __typename
      }
      telecom {
        system
        value
        __typename
      }
      __typename
    }
    father {
      id
      name {
        use
        firstNames
        middleName
        familyName
        __typename
      }
      birthDate
      maritalStatus
      occupation
      detailsExist
      reasonNotApplying
      ageOfIndividualInYears
      exactDateOfBirthUnknown
      dateOfMarriage
      educationalAttainment
      nationality
      identifier {
        id
        type
        otherType
        fieldsModifiedByIdentity
        __typename
      }
      address {
        type
        line
        district
        state
        city
        postalCode
        country
        __typename
      }
      telecom {
        system
        value
        __typename
      }
      __typename
    }
    registration {
      id
      informantType
      otherInformantType
      contact
      contactRelationship
      contactPhoneNumber
      contactEmail
      assignment {
        practitionerId
        firstName
        lastName
        officeName
        avatarURL
        __typename
      }
      certificates {
        hasShowedVerifiedDocument
        certificateTemplateId
        collector {
          relationship
          otherRelationship
          name {
            use
            firstNames
            familyName
            __typename
          }
          telecom {
            system
            value
            use
            __typename
          }
          __typename
        }
        __typename
      }
      duplicates {
        compositionId
        trackingId
        __typename
      }
      informantsSignature
      attachments {
        data
        uri
        type
        contentType
        subject
        __typename
      }
      status {
        comments {
          comment
          __typename
        }
        type
        timestamp
        office {
          name
          alias
          address {
            district
            state
            __typename
          }
          partOf
          __typename
        }
        __typename
      }
      type
      trackingId
      registrationNumber
      __typename
    }
    attendantAtBirth
    weightAtBirth
    birthType
    eventLocation {
      id
      type
      address {
        line
        district
        state
        city
        postalCode
        country
        __typename
      }
      __typename
    }
    questionnaire {
      fieldId
      value
      __typename
    }
    history {
      otherReason
      requester
      requesterOther
      noSupportingDocumentationRequired
      hasShowedVerifiedDocument
      certificateTemplateId
      date
      action
      regStatus
      dhis2Notification
      ipAddress
      documents {
        id
        data
        uri
        type
        __typename
      }
      payment {
        id
        type
        amount
        outcome
        date
        attachmentURL
        __typename
      }
      statusReason {
        text
        __typename
      }
      reason
      location {
        id
        name
        __typename
      }
      office {
        id
        name
        alias
        address {
          state
          district
          __typename
        }
        __typename
      }
      system {
        name
        type
        __typename
      }
      user {
        id
        role {
          id
          label {
            id
            defaultMessage
            description
            __typename
          }
          __typename
        }
        primaryOffice {
          id
          __typename
        }
        name {
          firstNames
          familyName
          use
          __typename
        }
        avatar {
          data
          type
          __typename
        }
        __typename
      }
      signature {
        data
        type
        __typename
      }
      comments {
        user {
          id
          username
          avatar {
            data
            type
            __typename
          }
          __typename
        }
        comment
        createdAt
        __typename
      }
      input {
        valueCode
        valueId
        value
        __typename
      }
      output {
        valueCode
        valueId
        value
        __typename
      }
      certificates {
        hasShowedVerifiedDocument
        certificateTemplateId
        collector {
          relationship
          otherRelationship
          name {
            use
            firstNames
            familyName
            __typename
          }
          telecom {
            system
            value
            use
            __typename
          }
          __typename
        }
        certifier {
          name {
            use
            firstNames
            familyName
            __typename
          }
          role {
            id
            label {
              id
              defaultMessage
              description
              __typename
            }
            __typename
          }
          __typename
        }
        __typename
      }
      duplicateOf
      potentialDuplicates
      __typename
    }
    __typename
  }
}
`,
    }),
  });

  if (!response.ok) {
    throw new Error(`GraphQL request failed: ${response.statusText}`);
  }
  return response.json();
};

// Example usage:
const birthRegistrationData = await fetchBirthRegistration();
birthRegistrationData
// Out:
// {
//   data: {
//     fetchBirthRegistration: {
//       _fhirIDMap: {
//         composition: "e68a3b3b-e7f0-42d4-9035-313dca4df0f0",
//         encounter: "d03be571-383b-46cb-ba41-ce5997852adf",
//         eventLocation: "fb5b597d-8186-4513-af50-ecf929640ec1",
//         observation: {
//           birthType: "7c662057-00cf-4af4-a1ff-702015c781cf",
//           attendantAtBirth: "d96ab04e-a6c3-41ae-9cc8-14b9e8b999d2"
//         },
//         questionnaireResponse: "de0ce686-30af-47b8-950f-d0fb25a9cccf"
//       },
//       id: "e68a3b3b-e7f0-42d4-9035-313dca4df0f0",
//       child: {
//         id: "7a979345-80fa-40dc-bd5d-c1591fe3d5e0",
//         identifier: null,
//         name: [ [Object] ],
//         birthDate: "2025-03-11",
//         gender: "unknown",
//         __typename: "Person"
//       },
//       informant: {
//         id: "6931da94-2fbe-4f8f-bfde-d9f13ecb7f52",
//         relationship: "GRANDFATHER",
//         otherRelationship: null,
//         _fhirIDPatient: "c02cbfe5-3ae9-424a-81c1-9d6471c88ad4",
//         identifier: [ [Object] ],
//         name: [ [Object] ],
//         occupation: null,
//         nationality: [ "FAR" ],
//         birthDate: "1985-04-10",
//         ageOfIndividualInYears: null,
//         exactDateOfBirthUnknown: null,
//         address: [ [Object] ],
//         __typename: "RelatedPerson"
//       },
//       mother: {
//         id: "b1e61928-4e90-43c8-8376-d5cdb6b801dc",
//         name: [ [Object] ],
//         multipleBirth: null,
//         birthDate: "2005-04-16",
//         maritalStatus: "WIDOWED",
//         occupation: null,
//         detailsExist: true,
//         reasonNotApplying: null,
//         ageOfIndividualInYears: null,
//         exactDateOfBirthUnknown: null,
//         dateOfMarriage: null,
//         educationalAttainment: "POST_SECONDARY_ISCED_4",
//         nationality: [ "FAR" ],
//         identifier: [ [Object] ],
//         address: [ [Object] ],
//         telecom: null,
//         __typename: "Person"
//       },
//       father: {
//         id: "019f1403-7f31-4c62-98f2-dc6a590faa8a",
//         name: [ [Object] ],
//         birthDate: "2003-02-04",
//         maritalStatus: "WIDOWED",
//         occupation: null,
//         detailsExist: true,
//         reasonNotApplying: null,
//         ageOfIndividualInYears: null,
//         exactDateOfBirthUnknown: null,
//         dateOfMarriage: null,
//         educationalAttainment: "POST_SECONDARY_ISCED_4",
//         nationality: [ "GAB" ],
//         identifier: [ [Object] ],
//         address: [ [Object] ],
//         telecom: null,
//         __typename: "Person"
//       },
//       registration: {
//         id: "d232d9a0-6295-4d09-936a-59ff7fcf57a4",
//         informantType: "GRANDFATHER",
//         otherInformantType: null,
//         contact: null,
//         contactRelationship: null,
//         contactPhoneNumber: null,
//         contactEmail: "Alisha37@gmail.com",
//         assignment: {
//           practitionerId: "4e8bb8f8-b36c-4c50-b8d0-6a7fb8a7ffa3",
//           firstName: "Kennedy",
//           lastName: "Mweene",
//           officeName: "Ibombo District Office",
//           avatarURL: "https://eu.ui-avatars.com/api/?background=DEE5F2&color=222&name=Kennedy Mweene",
//           __typename: "AssignmentData"
//         },
//         certificates: [ null ],
//         duplicates: null,
//         informantsSignature: "https://minio.opencrvs.dev/events-v2-test-environment--ocrvs/8bd34bfc-1cb5-46a9-aa09-864d0f922348.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=oZDsSBm5dWSmlDf5%2F20250528%2Flocal%2Fs3%2Faws4_request&X-Amz-Date=20250528T132106Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=b769847f18d19ae28328ea0972846f633c8651c6e93538026670c95c4ab9491e",
//         attachments: [
//           [Object], [Object],
//           [Object], [Object],
//           [Object], [Object],
//           [Object], [Object],
//           [Object], [Object],
//           [Object], [Object],
//           [Object], [Object],
//           [Object]
//         ],
//         status: [
//           [Object], [Object],
//           [Object], [Object],
//           [Object], [Object],
//           [Object]
//         ],
//         type: "BIRTH",
//         trackingId: "BHSZQNL",
//         registrationNumber: null,
//         __typename: "Registration"
//       },
//       attendantAtBirth: "MIDWIFE",
//       weightAtBirth: null,
//       birthType: "TRIPLET",
//       eventLocation: {
//         id: "fb5b597d-8186-4513-af50-ecf929640ec1",
//         type: "PRIVATE_HOME",
//         address: {
//           line: [Array],
//           district: "209fdd56-61e5-498f-8ffb-562857b7cea7",
//           state: "4cfef7dd-99ce-4123-8426-715d30f5e14b",
//           city: "",
//           postalCode: "",
//           country: "FAR",
//           __typename: "Address"
//         },
//         __typename: "Location"
//       },
//       questionnaire: [
//         {
//           fieldId: "birth.informant.informant-view-group.informantIdType",
//           value: "NATIONAL_ID",
//           __typename: "QuestionnaireQuestion"
//         },
//         {
//           fieldId: "birth.mother.mother-view-group.motherIdType",
//           value: "BIRTH_REGISTRATION_NUMBER",
//           __typename: "QuestionnaireQuestion"
//         },
//         {
//           fieldId: "birth.father.father-view-group.fatherIdType",
//           value: "BIRTH_REGISTRATION_NUMBER",
//           __typename: "QuestionnaireQuestion"
//         },
//         {
//           fieldId: "birth.informant.informant-view-group.verified",
//           value: "failed",
//           __typename: "QuestionnaireQuestion"
//         }
//       ],
//       history: [
//         {
//           otherReason: "",
//           requester: "",
//           requesterOther: "",
//           noSupportingDocumentationRequired: false,
//           hasShowedVerifiedDocument: false,
//           certificateTemplateId: null,
//           date: "2025-05-28T13:21:06.772Z",
//           action: "ASSIGNED",
//           regStatus: "VALIDATED",
//           dhis2Notification: false,
//           ipAddress: null,
//           documents: [],
//           payment: null,
//           statusReason: null,
//           reason: null,
//           location: [Object],
//           office: [Object],
//           system: null,
//           user: [Object],
//           signature: null,
//           comments: [],
//           input: [],
//           output: [],
//           certificates: [Array],
//           duplicateOf: null,
//           potentialDuplicates: null,
//           __typename: "History"
//         },
//         {
//           otherReason: "",
//           requester: "",
//           requesterOther: "",
//           noSupportingDocumentationRequired: false,
//           hasShowedVerifiedDocument: false,
//           certificateTemplateId: null,
//           date: "2025-05-28T13:20:21.737+00:00",
//           action: "ASSIGNED",
//           regStatus: "VALIDATED",
//           dhis2Notification: false,
//           ipAddress: null,
//           documents: [],
//           payment: null,
//           statusReason: null,
//           reason: null,
//           location: [Object],
//           office: [Object],
//           system: null,
//           user: [Object],
//           signature: null,
//           comments: [],
//           input: [],
//           output: [],
//           certificates: [Array],
//           duplicateOf: null,
//           potentialDuplicates: null,
//           __typename: "History"
//         },
//         {
//           otherReason: "",
//           requester: "",
//           requesterOther: "",
//           noSupportingDocumentationRequired: false,
//           hasShowedVerifiedDocument: false,
//           certificateTemplateId: null,
//           date: "2025-05-28T13:12:34.768+00:00",
//           action: "ASSIGNED",
//           regStatus: "VALIDATED",
//           dhis2Notification: false,
//           ipAddress: null,
//           documents: [],
//           payment: null,
//           statusReason: null,
//           reason: null,
//           location: [Object],
//           office: [Object],
//           system: null,
//           user: [Object],
//           signature: null,
//           comments: [],
//           input: [],
//           output: [],
//           certificates: [Array],
//           duplicateOf: null,
//           potentialDuplicates: null,
//           __typename: "History"
//         },
//         {
//           otherReason: "",
//           requester: "",
//           requesterOther: "",
//           noSupportingDocumentationRequired: false,
//           hasShowedVerifiedDocument: false,
//           certificateTemplateId: null,
//           date: "2025-05-28T13:11:37.197+00:00",
//           action: "ASSIGNED",
//           regStatus: "VALIDATED",
//           dhis2Notification: false,
//           ipAddress: null,
//           documents: [],
//           payment: null,
//           statusReason: null,
//           reason: null,
//           location: [Object],
//           office: [Object],
//           system: null,
//           user: [Object],
//           signature: null,
//           comments: [],
//           input: [],
//           output: [],
//           certificates: [Array],
//           duplicateOf: null,
//           potentialDuplicates: null,
//           __typename: "History"
//         },
//         {
//           otherReason: "",
//           requester: "",
//           requesterOther: "",
//           noSupportingDocumentationRequired: false,
//           hasShowedVerifiedDocument: false,
//           certificateTemplateId: null,
//           date: "2025-05-28T07:19:12.016+00:00",
//           action: "ASSIGNED",
//           regStatus: "VALIDATED",
//           dhis2Notification: false,
//           ipAddress: null,
//           documents: [],
//           payment: null,
//           statusReason: null,
//           reason: null,
//           location: [Object],
//           office: [Object],
//           system: null,
//           user: [Object],
//           signature: null,
//           comments: [],
//           input: [],
//           output: [],
//           certificates: [Array],
//           duplicateOf: null,
//           potentialDuplicates: null,
//           __typename: "History"
//         },
//         {
//           otherReason: "",
//           requester: "",
//           requesterOther: "",
//           noSupportingDocumentationRequired: false,
//           hasShowedVerifiedDocument: false,
//           certificateTemplateId: null,
//           date: "2025-05-28T07:19:00.380+00:00",
//           action: null,
//           regStatus: "VALIDATED",
//           dhis2Notification: false,
//           ipAddress: null,
//           documents: [],
//           payment: null,
//           statusReason: null,
//           reason: null,
//           location: [Object],
//           office: [Object],
//           system: null,
//           user: [Object],
//           signature: null,
//           comments: [],
//           input: [],
//           output: [],
//           certificates: [Array],
//           duplicateOf: null,
//           potentialDuplicates: null,
//           __typename: "History"
//         },
//         {
//           otherReason: "",
//           requester: "",
//           requesterOther: "",
//           noSupportingDocumentationRequired: false,
//           hasShowedVerifiedDocument: false,
//           certificateTemplateId: null,
//           date: "2025-05-28T07:19:00.165+00:00",
//           action: null,
//           regStatus: "DECLARED",
//           dhis2Notification: false,
//           ipAddress: null,
//           documents: [],
//           payment: null,
//           statusReason: null,
//           reason: null,
//           location: [Object],
//           office: [Object],
//           system: null,
//           user: [Object],
//           signature: null,
//           comments: [],
//           input: [],
//           output: [],
//           certificates: [Array],
//           duplicateOf: null,
//           potentialDuplicates: null,
//           __typename: "History"
//         }
//       ],
//       __typename: "BirthRegistration"
//     }
//   }
// }

// %%
import { v4 as uuidv4 } from 'npm:uuid';

const createBirthEvent = async () => {
  const transactionId = `tmp-${uuidv4()}`;
  const payload = {
    json: {
      type: "v2.birth",
      transactionId,
      declaration: null
    },
    meta: {
      values: {
        declaration: ["undefined"]
      }
    }
  };

  const response = await fetch(`${GATEWAY}/events/event.create`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json', Authorization: `Bearer ${token}` },
    body: JSON.stringify(payload)
  });

  if (!response.ok) {
    throw new Error(`Event creation failed: ${response.statusText}`);
  }
  return response.json();
};

// Example usage:
const eventResponse = await createBirthEvent();
const eventId = eventResponse.result.data.json.id

// %%
const authenticateJCampbell = async () => {
  const response = await fetch(`${GATEWAY}/auth/authenticate`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json' },
    body: JSON.stringify({ username: 'j.campbell', password: 'test' })
  });
  if (!response.ok) {
    throw new Error(`Authentication failed: ${response.statusText}`);
  }
  return response.json();
};

const nonceJCampbell = (await authenticateJCampbell()).nonce;

const verifyCodeJCampbell = async (code: string, nonce: string) => {
  const response = await fetch(`${GATEWAY}/auth/verifyCode`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json' },
    body: JSON.stringify({ code, nonce })
  });
  if (!response.ok) {
    throw new Error(`Code verification failed: ${response.statusText}`);
  }
  return response.json();
};

const tokenJCampbell = (await verifyCodeJCampbell('000000', nonceJCampbell)).token;

// %%
const registerSystem = async () => {
  const response = await fetch(`${GATEWAY}/graphql`, {
    method: "POST",
    headers: {
      "Content-Type": "application/json",
      Authorization: `Bearer ${tokenJCampbell}`,
    },
    body: JSON.stringify({
      operationName: "registerSystem",
      variables: {
        system: {
          type: "IMPORT",
          name: "Import"
        }
      },
      query: `mutation registerSystem($system: SystemInput) {
        registerSystem(system: $system) {
          clientSecret
          system {
            _id
            clientId
            name
            shaSecret
            status
            type
            integratingSystemType
            settings {
              webhook {
                event
                permissions
                __typename
              }
              __typename
            }
            __typename
          }
          __typename
        }
      }`
    }),
  });

  if (!response.ok) {
    throw new Error(`GraphQL request failed: ${response.statusText}`);
  }
  return response.json();
};

// Example usage:
const systemRegistration = await registerSystem();
const clientId = systemRegistration.data.registerSystem.system.clientId;
const clientSecret = systemRegistration.data.registerSystem.clientSecret;

// %%
async function getTokenForSystemClient(
  clientId: string,
  clientSecret: string
): Promise<string> {
  const authenticateResponse = await fetch(
    `${GATEWAY}/auth/token?client_id=${clientId}&client_secret=${clientSecret}&grant_type=client_credentials`,
    {
      method: 'POST',
      headers: {
        'Content-Type': 'application/json',
        'x-correlation-id': clientId + '-' + Date.now()
      }
    }
  );
  const res = await authenticateResponse.json();

  return res.token || res.access_token;
}

// %%
import { transform } from './transform.ts'

const document = transform(birthRegistrationData.data.fetchBirthRegistration)
document
// Out:
// {
//   id: "e68a3b3b-e7f0-42d4-9035-313dca4df0f0",
//   type: "v2.birth",
//   createdAt: "2025-05-28T07:19:00.165Z",
//   updatedAt: "2025-05-28T07:19:00.380Z",
//   updatedAtLocation: "32ee42dd-4afc-40ad-802e-971c586e895b",
//   trackingId: "BHSZQNL",
//   actions: [
//     {
//       type: "CREATE",
//       createdAt: "2025-05-28T07:19:00.165Z",
//       createdBy: "6836b85fde5bbdd189d6ed0e",
//       createdByRole: "REGISTRATION_AGENT",
//       createdAtLocation: "32ee42dd-4afc-40ad-802e-971c586e895b",
//       updatedAtLocation: "32ee42dd-4afc-40ad-802e-971c586e895b",
//       status: "Accepted",
//       declaration: {},
//       id: "bae16bbb-38eb-45b1-a78f-b2bee869bce9",
//       transactionId: "9de4851b-95c4-4b97-8c4e-7fdca04c3009"
//     },
//     {
//       id: "a9f3c720-20ba-4b64-8eaf-6e662ffdf3a1",
//       transactionId: "57274672-ef43-4856-8bd2-ca918e271cb9",
//       createdAt: "2025-05-28T07:19:00.165Z",
//       createdBy: "6836b85fde5bbdd189d6ed0e",
//       createdByRole: "REGISTRATION_AGENT",
//       createdAtLocation: "32ee42dd-4afc-40ad-802e-971c586e895b",
//       updatedAtLocation: "32ee42dd-4afc-40ad-802e-971c586e895b",
//       status: "Accepted",
//       type: "DECLARE",
//       declaration: {
//         "child.firstname": "Jasmin_Peter",
//         "child.middleName": "",
//         "child.surname": "Rohan",
//         "child.gender": "unknown",
//         "child.dob": "2025-03-11",
//         "child.placeOfBirth": "PRIVATE_HOME",
//         "child.birthLocation": "fb5b597d-8186-4513-af50-ecf929640ec1",
//         "child.address.privateHome": {
//           country: "FAR",
//           addressType: "INTERNATIONAL",
//           state: "4cfef7dd-99ce-4123-8426-715d30f5e14b",
//           district2: "209fdd56-61e5-498f-8ffb-562857b7cea7",
//           cityOrTown: "",
//           addressLine1: "Bedfordshire",
//           addressLine2: "RURAL",
//           addressLine3: "",
//           postcodeOrZip: ""
//         },
//         "child.attendantAtBirth": "MIDWIFE",
//         "child.birthType": "TRIPLET",
//         "informant.dob": "1985-04-10",
//         "informant.address": {
//           country: "FAR",
//           addressType: "INTERNATIONAL",
//           state: "d2691cd9-afd5-43c1-bed0-1b43b580795f",
//           district2: "59069be4-f690-44f6-a08c-d6a38c5a95ec",
//           cityOrTown: "Hackettstead",
//           addressLine1: "942",
//           addressLine2: "Ahmad Streets",
//           addressLine3: "Logan County, URBAN",
//           postcodeOrZip: "14458"
//         },
//         "informant.email": "Alisha37@gmail.com",
//         "informant.relation": "GRANDFATHER",
//         "informant.firstname": "Julio",
//         "informant.middleName": "",
//         "informant.surname": "Morissette",
//         "informant.nationality": "FAR",
//         "mother.detailsNotAvailable": false,
//         "mother.firstname": "Sophia",
//         "mother.surname": "Von",
//         "mother.dob": "2005-04-16",
//         "mother.nationality": "FAR",
//         "mother.maritalStatus": "WIDOWED",
//         "mother.educationalAttainment": "POST_SECONDARY_ISCED_4",
//         "mother.address": {
//           country: "DJI",
//           addressType: "INTERNATIONAL",
//           state: "Alabama",
//           district2: "Strathclyde",
//           cityOrTown: "Rodrigueztown",
//           addressLine1: "Calhoun County",
//           addressLine2: "Russell Street",
//           addressLine3: "18592",
//           postcodeOrZip: "08005"
//         },
//         "father.detailsNotAvailable": false,
//         "father.firstname": "Bert",
//         "father.surname": "Runte",
//         "father.dob": "2003-02-04",
//         "father.nationality": "GAB",
//         "father.maritalStatus": "WIDOWED",
//         "father.educationalAttainment": "POST_SECONDARY_ISCED_4",
//         "documents.proofOfBirth": {
//           filename: "/events-v2-test-environment--ocrvs/06fba66d-4c31-4eef-a861-3f83895d1e00.png",
//           originalFilename: "/events-v2-test-environment--ocrvs/06fba66d-4c31-4eef-a861-3f83895d1e00.png",
//           type: "image/png"
//         },
//         "documents.proofOfMother": [ [Object] ],
//         "documents.proofOfFather": [ [Object] ],
//         "documents.proofOfInformant": [ [Object] ],
//         "informant.idType": "NATIONAL_ID",
//         "mother.idType": "BIRTH_REGISTRATION_NUMBER",
//         "father.idType": "BIRTH_REGISTRATION_NUMBER",
//         "mother.brn": "625210237",
//         "father.brn": "42778162663",
//         "informant.nid": "6823369022"
//       },
//       annotation: {
//         "review.signature": "https://minio.opencrvs.dev/events-v2-test-environment--ocrvs/8bd34bfc-1cb5-46a9-aa09-864d0f922348.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=oZDsSBm5dWSmlDf5%2F20250528%2Flocal%2Fs3%2Faws4_request&X-Amz-Date=20250528T132106Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=b769847f18d19ae28328ea0972846f633c8651c6e93538026670c95c4ab9491e",
//         "review.comment": ""
//       }
//     },
//     {
//       id: "a40d28f4-a937-4ba4-9ab4-fb26a2259ffd",
//       transactionId: "e2110411-9979-4c5c-9e9a-339b747ec074",
//       createdAt: "2025-05-28T07:19:00.380Z",
//       createdBy: "6836b85fde5bbdd189d6ed0e",
//       createdByRole: "REGISTRATION_AGENT",
//       createdAtLocation: "32ee42dd-4afc-40ad-802e-971c586e895b",
//       updatedAtLocation: "32ee42dd-4afc-40ad-802e-971c586e895b",
//       status: "Accepted",
//       type: "VALIDATE",
//       declaration: {}
//     }
//   ]
// }

// %%
const sysToken = await getTokenForSystemClient(clientId, clientSecret);

const declareBirthEvent = async () => {
  const response = await fetch(`${GATEWAY}/events/event.import`, {
    method: 'POST',
    headers: { 'Content-Type': 'application/json', Authorization: `Bearer ${sysToken}` },
    body: JSON.stringify({json: document, meta: {
      values: {
        declaration: ["undefined"]
      }
    }})
  });

  if (!response.ok) {
    console.log((await response.json()).error.json.message);


    throw new Error(`Event creation failed: ${response.statusText}`);
  }
  return response.json();
};

const result = await declareBirthEvent()

// %%
console.log('🍞 Declaration with ID', RECORD_ID, 'was succesfully migrated!')
console.log()
console.log('You can view the record', `[here](https://register.${domain}/events/view/${result.result.data.json.id}?V2_EVENTS=true)`)
// Out:
// Declaration with ID e68a3b3b-e7f0-42d4-9035-313dca4df0f0
// You can view the record [here](https://register.events-v2-test-environment.opencrvs.dev/events/view/e68a3b3b-e7f0-42d4-9035-313dca4df0f0?V2_EVENTS=true)
// You can view the record [here](https://register.events-v2-test-environment.opencrvs.dev/events/view/e68a3b3b-e7f0-42d4-9035-313dca4df0f0?V2_EVENTS=true)
