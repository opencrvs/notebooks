// %%
import { registerSystem } from './helpers/gqlHandlers.ts'
import { authenticate, getTokenForSystemClient } from './helpers/authentication.ts'
import { CLIENT_ID, CLIENT_SECRET } from './helpers/vars.ts'
import { ADMIN_USERNAME, ADMIN_PASSWORD } from './helpers/vars.ts'


let clientId: string | null = null
let clientSecret: string | null = null

if (CLIENT_ID && CLIENT_SECRET) {
  clientId = CLIENT_ID
  clientSecret = CLIENT_SECRET
} else {
  // For dev mode
  const adminToken = await authenticate(ADMIN_USERNAME, ADMIN_PASSWORD)
  const systemRegistration = await registerSystem(adminToken)

  clientId = systemRegistration.data.registerSystem.system.clientId
  clientSecret = systemRegistration.data.registerSystem.clientSecret
}

const sysToken = await getTokenForSystemClient(clientId, clientSecret)
sysToken
// Out:
// "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....N0BUdbU4xDvt5Hgyv6KHP4MEeydIF6PmZZRt1IqCVuo_ROtG0zVTUWfYYkpS4IwUtEVRyITzRGRfnOSzezoV5foXuPg34DZOQKNQVoTQ-mg57NBRzRhV57T-tyuiFcqSim4BYLzBFXNFG61aG3jEaliq6WWFR-QuUA-hD6e-QEHtCIdAyZ-Z5coRS2o3xPfP8VdbUwOKACksSR1WxswhQR-ekfmpSxuSyK0SZxFrC7GVJEVXcNvGQSPhelkUk2mlIkYTGDFu3TMD-w97sPof7L7sRwup0Z7TFEkyTbHwYaYAa-K8Oz4twWW-5jq_9matxafImwnLnxfpm7V6izY_Tw"

// %%
import {
  fetchBirthRegistration,
  bulkImport,
  fetchAllBirthRegistrations,
} from './helpers/gqlHandlers.ts'

const document = {
  id: 'f1b45cd4-a23f-44db-8d0c-1c043fe0094c',
  type: 'birth',
  createdAt: '2025-11-11T08:21:05.880Z',
  updatedAt: '2026-01-06T10:32:55.657Z',
  updatedAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
  trackingId: 'BLVTAF2',
  actions: [
    {
      id: '59c3a0e1-b2cb-4bf2-93d5-8a366cc581d8',
      transactionId: '7fdedfe2-93dd-4111-abb0-44aa0ef4afcd',
      createdByUserType: 'user',
      createdAt: '2025-11-11T08:21:05.880Z',
      createdBy: '695d035a8c10e13564010069',
      createdByRole: 'REGISTRATION_AGENT',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {},
      status: 'Accepted',
      type: 'CREATE',
    },
    {
      id: '2bd3c6c8-8c6a-4a96-818a-326fcfb5fb6a',
      transactionId: '26329610-86d3-499d-a8d2-51c218c84904',
      createdByUserType: 'user',
      createdAt: '2025-11-11T08:21:05.880Z',
      createdBy: '695d035a8c10e13564010069',
      createdByRole: 'REGISTRATION_AGENT',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {
        'child.dob': '2020-08-18',
        'child.nid': '8191256205',
        'child.name': {
          surname: 'Manheim-Mannheim-McQuack',
          firstname: 'Hollyhock',
          middleName: '',
        },
        'father.dob': '2000-04-13',
        'father.nid': '1234567967',
        'mother.dob': '2000-05-14',
        'mother.nid': '',
        'father.name': {
          surname: 'Jayawardena',
          firstname: 'Mahesh',
          middleName: '',
        },
        'mother.name': {
          surname: 'Tasnim',
          firstname: 'Farhana',
          middleName: '',
        },
        'child.gender': 'female',
        'child.reason': 'delayed',
        'father.idType': 'NATIONAL_ID',
        'mother.idType': 'NONE',
        'father.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'mother.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'child.birthType': 'TWIN',
        'father.verified': 'verified',
        'informant.email': 'mahesh@test-mail.com',
        'child.placeOfBirth': 'HEALTH_FACILITY',
        'father.nationality': 'FAR',
        'informant.relation': 'FATHER',
        'mother.nationality': 'FAR',
        'child.birthLocation': 'ddc5501e-0201-47b7-a232-2cc8ca1970d0',
        'child.weightAtBirth': 0,
        'documents.proofOther': [],
        'father.addressSameAs': 'YES',
        'mother.maritalStatus': '',
        'child.attendantAtBirth': 'TRADITIONAL_BIRTH_ATTENDANT',
        'father.detailsNotAvailable': false,
        'mother.detailsNotAvailable': false,
        'mother.educationalAttainment': '',
      },
      annotation: {
        'review.comment': '',
        'review.signature': {
          path: '/ocrvs/f1caf1f5-3998-427e-bc07-190488653ceb.png',
          type: 'image/png',
          originalFilename: 'f1caf1f5-3998-427e-bc07-190488653ceb.png',
        },
      },
      status: 'Accepted',
      type: 'DECLARE',
    },
    {
      id: '84f9ffce-0020-4b74-944c-9a0e1bbf6bc1',
      transactionId: '3bd7feac-fd4b-45ba-9e0f-51ad9196d67a',
      createdByUserType: 'user',
      createdAt: '2025-11-11T08:21:06.013Z',
      createdBy: '695d035a8c10e13564010069',
      createdByRole: 'REGISTRATION_AGENT',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {
        'child.dob': '2020-08-18',
        'child.nid': '8191256205',
        'child.name': {
          surname: 'Manheim-Mannheim-McQuack',
          firstname: 'Hollyhock',
          middleName: '',
        },
        'father.dob': '2000-04-13',
        'father.nid': '1234567967',
        'mother.dob': '2000-05-14',
        'mother.nid': '',
        'father.name': {
          surname: 'Jayawardena',
          firstname: 'Mahesh',
          middleName: '',
        },
        'mother.name': {
          surname: 'Tasnim',
          firstname: 'Farhana',
          middleName: '',
        },
        'child.gender': 'female',
        'child.reason': 'delayed',
        'father.idType': 'NATIONAL_ID',
        'mother.idType': 'NONE',
        'father.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'mother.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'child.birthType': 'TWIN',
        'father.verified': 'verified',
        'informant.email': 'mahesh@test-mail.com',
        'child.placeOfBirth': 'HEALTH_FACILITY',
        'father.nationality': 'FAR',
        'informant.relation': 'FATHER',
        'mother.nationality': 'FAR',
        'child.birthLocation': 'ddc5501e-0201-47b7-a232-2cc8ca1970d0',
        'child.weightAtBirth': 0,
        'documents.proofOther': [],
        'father.addressSameAs': 'YES',
        'mother.maritalStatus': '',
        'child.attendantAtBirth': 'TRADITIONAL_BIRTH_ATTENDANT',
        'father.detailsNotAvailable': false,
        'mother.detailsNotAvailable': false,
        'mother.educationalAttainment': '',
      },
      annotation: {
        'review.comment': '',
        'review.signature': {
          path: '/ocrvs/f1caf1f5-3998-427e-bc07-190488653ceb.png',
          type: 'image/png',
          originalFilename: 'f1caf1f5-3998-427e-bc07-190488653ceb.png',
        },
      },
      status: 'Accepted',
      type: 'VALIDATE',
    },
    {
      id: '18381e77-6836-4e09-b85b-8e2c3977b948',
      transactionId: '95dbe2ba-f85c-4fdc-b1f3-e3b6ec8c64ac',
      createdByUserType: 'user',
      createdAt: '2025-11-11T08:21:31.417Z',
      createdBy: '6509920c42f19d1950648ea8',
      createdByRole: 'LOCAL_REGISTRAR',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {},
      status: 'Accepted',
      type: 'ASSIGN',
      assignedTo: '6509920c42f19d1950648ea8',
    },
    {
      id: '7daeb4c4-20c2-42cf-bcd1-ee4390fa19ee',
      transactionId: '15b9583c-8e96-414c-bc7e-ec654f3360ce',
      createdByUserType: 'user',
      createdAt: '2025-11-11T08:23:37.346Z',
      createdBy: '6509920c42f19d1950648ea8',
      createdByRole: 'LOCAL_REGISTRAR',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {
        'child.dob': '2020-08-18',
        'child.nid': '8191256205',
        'child.name': {
          surname: 'Manheim-Mannheim-McQuack',
          firstname: 'Hollyhock',
          middleName: '',
        },
        'father.dob': '2000-04-13',
        'father.nid': '1234567967',
        'mother.dob': '2000-08-10',
        'mother.nid': '1234567945',
        'father.name': {
          surname: 'Jayawardena',
          firstname: 'Mahesh',
          middleName: '',
        },
        'mother.name': {
          surname: 'Perera',
          firstname: 'Sulochana',
          middleName: '',
        },
        'child.gender': 'female',
        'child.reason': 'delayed',
        'father.idType': 'NATIONAL_ID',
        'mother.idType': 'NATIONAL_ID',
        'father.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'mother.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'child.birthType': 'TWIN',
        'father.verified': 'verified',
        'informant.email': 'mahesh@test-mail.com',
        'mother.verified': 'verified',
        'child.placeOfBirth': 'HEALTH_FACILITY',
        'father.nationality': 'FAR',
        'informant.relation': 'FATHER',
        'mother.nationality': 'FAR',
        'child.birthLocation': 'ddc5501e-0201-47b7-a232-2cc8ca1970d0',
        'child.weightAtBirth': 0,
        'documents.proofOther': [],
        'father.addressSameAs': 'YES',
        'mother.maritalStatus': 'NOT_STATED',
        'child.attendantAtBirth': 'TRADITIONAL_BIRTH_ATTENDANT',
        'father.detailsNotAvailable': false,
        'mother.detailsNotAvailable': false,
        'mother.educationalAttainment': 'PRIMARY_ISCED_1',
      },
      annotation: {
        'child.dob': '2020-08-18',
        'child.nid': '8191256205',
        'child.name': {
          surname: 'Manheim-Mannheim-McQuack',
          firstname: 'Hollyhock',
          middleName: '',
        },
        'father.dob': '2000-04-13',
        'father.nid': '1234567967',
        'mother.dob': '2000-05-14',
        'mother.nid': '',
        'father.name': {
          surname: 'Jayawardena',
          firstname: 'Mahesh',
          middleName: '',
        },
        'mother.name': {
          surname: 'Tasnim',
          firstname: 'Farhana',
          middleName: '',
        },
        'child.gender': 'female',
        'child.reason': 'delayed',
        'father.idType': 'NATIONAL_ID',
        'mother.idType': 'NONE',
        'father.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'mother.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'child.birthType': 'TWIN',
        'father.verified': 'verified',
        'informant.email': 'mahesh@test-mail.com',
        'child.placeOfBirth': 'HEALTH_FACILITY',
        'father.nationality': 'FAR',
        'informant.relation': 'FATHER',
        'mother.nationality': 'FAR',
        'child.birthLocation': 'ddc5501e-0201-47b7-a232-2cc8ca1970d0',
        'child.weightAtBirth': 0,
        'documents.proofOther': [],
        'father.addressSameAs': 'YES',
        'mother.maritalStatus': '',
        'child.attendantAtBirth': 'TRADITIONAL_BIRTH_ATTENDANT',
        'father.detailsNotAvailable': false,
        'mother.detailsNotAvailable': false,
        'mother.educationalAttainment': '',
      },
      status: 'Accepted',
      type: 'DECLARE',
    },
    {
      id: '86d9e368-bfb7-4889-9c00-385a60d09555',
      transactionId: '4ad41d9f-c5e7-4057-bf39-4b0083f9f60f',
      createdByUserType: 'user',
      createdAt: '2025-11-11T08:23:38.018Z',
      createdBy: '6509920c42f19d1950648ea8',
      createdByRole: 'LOCAL_REGISTRAR',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {},
      status: 'Requested',
      type: 'REGISTER',
    },
    {
      id: '771a9570-0f76-47ec-8764-f47aff8c58a6',
      transactionId: '17bf4765-0d4c-4ca9-995f-9d08119295f6',
      createdByUserType: 'user',
      createdAt: '2025-11-11T08:23:50.135Z',
      createdBy: '6509920c42f19d1950648ea8',
      createdByRole: 'LOCAL_REGISTRAR',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {
        'child.dob': '2020-08-18',
        'child.nid': '8191256205',
        'child.name': {
          surname: 'Manheim-Mannheim-McQuack',
          firstname: 'Hollyhock',
          middleName: '',
        },
        'father.dob': '2000-04-13',
        'father.nid': '1234567967',
        'mother.dob': '2000-08-10',
        'mother.nid': '1234567945',
        'father.name': {
          surname: 'Jayawardena',
          firstname: 'Mahesh',
          middleName: '',
        },
        'mother.name': {
          surname: 'Perera',
          firstname: 'Sulochana',
          middleName: '',
        },
        'child.gender': 'female',
        'child.reason': 'delayed',
        'father.idType': 'NATIONAL_ID',
        'mother.idType': 'NATIONAL_ID',
        'father.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'mother.address': {
          country: 'FAR',
          addressType: 'DOMESTIC',
          administrativeArea: '74ff0b61-683a-4189-9b87-cc2368b09fe0',
          streetLevelDetails: {
            town: null,
            zipCode: null,
          },
        },
        'child.birthType': 'TWIN',
        'father.verified': 'verified',
        'informant.email': 'mahesh@test-mail.com',
        'mother.verified': 'verified',
        'child.placeOfBirth': 'HEALTH_FACILITY',
        'father.nationality': 'FAR',
        'informant.relation': 'FATHER',
        'mother.nationality': 'FAR',
        'child.birthLocation': 'ddc5501e-0201-47b7-a232-2cc8ca1970d0',
        'child.weightAtBirth': 0,
        'documents.proofOther': [],
        'father.addressSameAs': 'YES',
        'mother.maritalStatus': 'NOT_STATED',
        'child.attendantAtBirth': 'TRADITIONAL_BIRTH_ATTENDANT',
        'father.detailsNotAvailable': false,
        'mother.detailsNotAvailable': false,
        'mother.educationalAttainment': 'PRIMARY_ISCED_1',
      },
      annotation: {
        'review.comment': '',
        'review.signature': {
          path: '/ocrvs/f1caf1f5-3998-427e-bc07-190488653ceb.png',
          type: 'image/png',
          originalFilename: 'f1caf1f5-3998-427e-bc07-190488653ceb.png',
        },
      },
      status: 'Accepted',
      type: 'REGISTER',
      registrationNumber: '2025BLVTAF2',
    },
    {
      id: '8e036147-633c-42d7-86d7-7fcb6b193c03',
      transactionId: 'dd8f9e6f-5f10-4afd-8aa8-7ef3414ed853',
      createdByUserType: 'user',
      createdAt: '2025-11-11T08:23:56.738Z',
      createdBy: '6509920c42f19d1950648ea8',
      createdByRole: 'LOCAL_REGISTRAR',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {},
      status: 'Accepted',
      type: 'READ',
    },
    {
      id: '2b9287f1-549b-41de-8e57-deaf898166b0',
      transactionId: '6e5307ae-ee6c-4e39-9233-48813b9e72ee',
      createdByUserType: 'user',
      createdAt: '2025-12-22T05:53:14.360Z',
      createdBy: '6509920c42f19d1950648ea8',
      createdByRole: 'LOCAL_REGISTRAR',
      createdBySignature: '/ocrvs/0840890e-1ed8-4465-ba1a-2d8031960bc0.png',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {},
      status: 'Accepted',
      type: 'READ',
    },
    {
      id: '4600e7fe-5079-4321-96e1-c8a477b8c470',
      transactionId: 'aee09839-2b1e-4f44-a81d-50071a3db7cd',
      createdByUserType: 'user',
      createdAt: '2026-01-06T10:33:21.119Z',
      createdBy: '6509920c42f19d1950648ea8',
      createdByRole: 'LOCAL_REGISTRAR',
      createdBySignature: '/ocrvs/0840890e-1ed8-4465-ba1a-2d8031960bc0.png',
      createdAtLocation: 'f179eb69-bf68-4076-a267-f222669b43d6',
      declaration: {},
      status: 'Accepted',
      type: 'READ',
    },
  ],
}

await bulkImport([document], sysToken)
// Out:
// {
//   result: {
//     data: { json: { errors: false, took: 0, items: [ [Object] ] } }
//   }
// }
// Stack trace:
// TypeError: Body already consumed
//     at InnerBody.consume (ext:deno_fetch/22_body.js:157:32)
//     at consumeBody (ext:deno_fetch/22_body.js:268:34)
//     at Response.json (ext:deno_fetch/22_body.js:359:16)
//     at bulkImport (file:///home/baz/code/openCRVS/notebooks/v1-to-v2-data-migration/helpers/gqlHandlers.ts:54:19)
//     at eventLoopTick (ext:core/01_core.js:178:7)
//     at async <anonymous>:463:1

// %%
import { fetchEvents } from './helpers/formsHandlers.ts'
import { extractFieldType } from './helpers/utils.ts'

const events = await fetchEvents(sysToken)

const ignoredFields = ['DIVIDER', 'PARAGRAPH']

const birthEvent = events.find((x) => x.id === 'birth')
const deathEvent = events.find((x) => x.id === 'death')

const birthEventFields = new Set(
  extractFieldType(birthEvent, 'fields')
    .filter((x) => !ignoredFields.includes(x.type))
    .map((f) => f.id)
    .filter((x) => x)
)

const deathEventFields = new Set(
  extractFieldType(deathEvent, 'fields')
    .filter((x) => !ignoredFields.includes(x.type))
    .map((f) => f.id)
    .filter((x) => x)
)
console.log([...birthEventFields].filter((x) => x.includes('informant')))

// %%
import defaultResolvers, {
  defaultBirthResolver,
  defaultDeathResolver,
} from './helpers/defaultResolvers.ts'
import { countryResolver } from './countryData/countryResolvers.ts'

const allResolvers = { ...defaultResolvers, ...countryResolver }

const birthResolver = Object.fromEntries(
  Object.entries({...defaultBirthResolver, ...allResolvers}).filter(([key, _value]) =>
    [...birthEventFields].includes(key)
  )
)

const deathResolver = Object.fromEntries(
  Object.entries({...defaultDeathResolver, ...allResolvers}).filter(([key, _value]) =>
    [...deathEventFields].includes(key)
  )
)
birthResolver

// %%
import { fetchBirthRegistration } from './helpers/gqlHandlers.ts'
import { EVENT } from './helpers/vars.ts'
let birthRegistrationData
if (EVENT === 'birth') {
  const entryId = 'f1b45cd4-a23f-44db-8d0c-1c043fe0094c'

  birthRegistrationData = await fetchBirthRegistration(entryId, sysToken)
  console.log(JSON.stringify(birthRegistrationData))
}

// %%
import { transform } from './helpers/transform.ts'

export const bulkImport = async (documents: any[], token: string) => {
  const response = await fetch(
    `http://localhost:7070/events/event.bulkImport`,
    {
      method: 'POST',
      headers: {
        'Content-Type': 'application/json',
        Authorization: `Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....M6ZXOcOu-IYEWn8-hQPIGkowDqu1sA3lFvTvAdE0nKX0tNLbeLFBQ0ruVviSJfAKLR5GiDRHbIJ-Z2YRModK6lMrRsrjBdaFcwoLxL9fDSiQLpgm9Tj_qrr0tFySUTaeqlGxqDrgpTc3m4d0fzlq4WfwoEB0Wr-MgEW3RxvcmnMqTfh-GzKEvOGcohL7U2FEefQwI1DZH5uvhS8GGkr02XV5yxn-q94oafBvJZ-rOmXx9fb_K-Os2bNYrRfIYdjJiwxksN__wi4yUVBW4VTAQ-1FvNVdb3nBqjbV3clXQpQEjOogkmJRDeo4IZYJHTdMPalxlTMutfBoo-7gHS7JkA`,
      },
      body: JSON.stringify({
        json: documents,
        meta: {
          values: {
            declaration: ['undefined'],
          },
        },
      }),
    }
  )

  if (!response.ok) {
    console.log('DECLARE ERROR!')
    console.log((await response.json()).error)

    throw new Error(`Event creation failed: ${response.statusText}`)
  }
  return response.json()
}

if (EVENT === 'birth') {
  //transform
  const document = transform(
    birthRegistrationData.data.fetchBirthRegistration,
    birthResolver,
    'birth'
  )
  console.log(JSON.stringify(document))
  const res = await bulkImport([document], sysToken)
  console.log(JSON.stringify(res))
  res
  //document?.actions //.filter(x => x.type === "PRINT_CERTIFICATE")
}

// %%
import { fetchDeathRegistration } from './helpers/gqlHandlers.ts'
import { transform } from './helpers/transform.ts'

const EVENT = 'death'

const entryId = 'f0610590-e25e-4b4c-8ea5-8e178fb1e0a8'
if (EVENT === 'death') {
  const deathRegistrationData = await fetchDeathRegistration(entryId, sysToken)
  console.log(JSON.stringify(deathRegistrationData))

  

  //transform
  const document = transform(
    deathRegistrationData.data.fetchDeathRegistration,
    deathResolver,
    'death'
  )

  document.actions //.filter(x => x.type === "PRINT_CERTIFICATE")
}
