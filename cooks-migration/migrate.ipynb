// %% [markdown]
// ### Authenticate
//
// Get the client id and secret from env vars for prod.
// In dev we can create a new client each time

// %%
import { registerSystem } from '../v1-to-v2-data-migration/helpers/gqlHandlers.ts'
import {
  authenticate,
  getTokenForSystemClient,
} from '../v1-to-v2-data-migration/helpers/authentication.ts'
import {
  CLIENT_ID,
  CLIENT_SECRET,
} from '../v1-to-v2-data-migration/helpers/vars.ts'
import {
  ADMIN_USERNAME,
  ADMIN_PASSWORD,
} from '../v1-to-v2-data-migration/helpers/vars.ts'

let clientId: string | null = null
let clientSecret: string | null = null

if (CLIENT_ID && CLIENT_SECRET) {
  clientId = CLIENT_ID
  clientSecret = CLIENT_SECRET
} else {
  // For dev mode
  const adminToken = await authenticate(ADMIN_USERNAME, ADMIN_PASSWORD)
  const systemRegistration = await registerSystem(adminToken)

  clientId = systemRegistration.data.registerSystem.system.clientId
  clientSecret = systemRegistration.data.registerSystem.clientSecret
}

const sysToken = await getTokenForSystemClient(clientId, clientSecret)
sysToken

// %% [markdown]
// ### Fetch data from CSVs

// %%
import { csvToJson } from './helpers/csvHelpers.ts'
import { CsvFields } from './helpers/csvTypes.ts'

// TODO Set paths to CSVs
const pathToBirthCsv = './sourceData/Birth_Register.csv'
const pathToDeathCsv = './sourceData/Death_Register.csv'
const pathToMarriageCsv = './sourceData/Marriage_Register.csv'
const pathToAdoptionCsv = './sourceData/Adoption_Register.csv'
const pathToDeedpollCsv = './sourceData/Deedpoll.csv'

const csvData: CsvFields = {
  birth: await csvToJson(pathToBirthCsv),
  death: await csvToJson(pathToDeathCsv),
  marriage: await csvToJson(pathToMarriageCsv),
  adoption: await csvToJson(pathToAdoptionCsv),
  deedpoll: await csvToJson(pathToDeedpollCsv)
}

// %%
import { GATEWAY } from '../v1-to-v2-data-migration/helpers/routes.ts'
import { Country } from './helpers/addressConfig.ts'
import { readJsonFile } from './helpers/csvHelpers.ts'
import { LocationMap } from './helpers/types.ts'
import { transform } from './helpers/transform.ts'
import {
  nonNullObjectKeys,
  toCrvsDate,
  toLegacy
} from './helpers/resolverHelpers.ts'

export const getLocations = async (
  token: string,
  type: 'ADMIN_STRUCTURE' | 'HEALTH_FACILITY'
) => {
  const response = await fetch(
    `${GATEWAY}/location?type=${type}&_count=0&status=active`,
    {
      method: 'GET',
      headers: {
        'Content-Type': 'application/json',
        Authorization: `Bearer ${token}`,
        Connection: 'close'
      },
      keepalive: false
    }
  )
  if (!response.ok) {
    throw new Error(`Sync Locations failed: ${response.statusText}`)
  }
  return response
}

const locationsRes = await getLocations(sysToken, 'ADMIN_STRUCTURE')
const healthFacilitiesRes = await getLocations(sysToken, 'HEALTH_FACILITY')
const fhirLocations = await locationsRes.json()
const fhirHealthFacilities = await healthFacilitiesRes.json()

const locationCodes = fhirLocations.entry
  .concat(fhirHealthFacilities.entry)
  .map((loc: any) => ({
    id: loc.resource.id,
    name: loc.resource.name,
    code:
      loc.resource.identifier[0]?.value
        .replace('ADMIN_STRUCTURE_', '')
        .replace('HEALTH_FACILITY_', '') || null
  }))

const intl: Record<string, { country: Country; town: string }> = readJsonFile(
  './lookupMappings/generated/intl.json'
)
const local: Record<string, string> = readJsonFile(
  './lookupMappings/generated/local.json'
)
const facility: Record<string, string> = readJsonFile(
  './lookupMappings/generated/facility.json'
)

const locationMap: LocationMap[] = []

Object.entries(intl).forEach(([key, value]) => {
  locationMap.push({
    id: '',
    name: key,
    country: value.country,
    intlTown: value.town.trim()
  })
})

Object.entries(local).forEach(([key, value]) => {
  locationMap.push({
    id: '',
    map: value,
    name: key
  })
})

Object.entries(facility).forEach(([key, value]) => {
  locationMap.push({
    id: '',
    facilityCode: value,
    name: key
  })
})

const updatedLocationsMap = locationMap.map((loc: any) => ({
  ...loc,
  id:
    locationCodes.find(
      (l: any) => l.code === loc.map || l.code === loc.facilityCode
    )?.id || null
}))

// %%
import { birthResolver, birthMetaData } from './mappings/birthResolver.ts'
import { bulkImport } from '../v1-to-v2-data-migration/helpers/gqlHandlers.ts'
import {
  batch,
  getIndexErrors
} from '../v1-to-v2-data-migration/helpers/utils.ts'
import {
  generateRegistrationNumber,
  writeTrackingIdsToFile
} from './helpers/generators.ts'
import { CrvsEvent } from './helpers/types.ts'
import { BirthMetaData, BirthResolver } from './helpers/birthTypes.ts'
import { nameChangeResolver } from './mappings/nameChangeResolver.ts'
import { NameChangeResolver } from './helpers/nameChangeTypes.ts'
import { DeathResolver } from './helpers/deathTypes.ts'
import { deathResolver, deathMetaData } from './mappings/deathResolver.ts'
import { MarriageResolver } from './helpers/marriageTypes.ts'
import {
  marriageResolver,
  marriageMetaData
} from './mappings/marriageResolver.ts'

const BATCH_SIZE = 1000
//const user = '699c5f51e5eca3ddfe2758fe' // staging
const user = '69942223e278e3066e57acdc' // CHANGE ME
//const centralLocationId = 'c5d093ea-c53e-48f1-af7e-ce7e52951e1b' // Staghing
const centralLocationId = '9d86dbca-0f1e-45b3-bf91-bfdaa5c51588' // Set Me
const role = 'REGISTRAR'

const batchImport = async (batch: CrvsEvent[], sysToken: string) => {
  const res = await bulkImport(batch, sysToken)
  const errors = getIndexErrors(res)
  if (errors) {
    console.error('Errors during bulk import', errors)
  }
}

const migrateEvents = async (events: CrvsEvent[], type: string) => {
  let imported = 0
  let remaining = events.length

  const batches = batch(events, BATCH_SIZE)

  console.log('Found ', events.length, ` ${type} events to import`)

  for (const batch of batches) {
    console.log(`Importing next ${batch.length} of remaining ${remaining}...`)
    try {
      await batchImport(batch, sysToken)
    } catch (error: any) {
      if (
        error.message?.includes('connection closed before message completed') // let's add a timeouet retry here
      ) {
        console.error('Connection closed error, retrying batch...')
        await batchImport(batch, sysToken)
      }
      if (error.message?.toLowerCase()?.includes('timeout')) {
        console.error('Timeout error, retrying batch...')
        await batchImport(batch, sysToken)
      }
      throw error
    }

    imported += batch.length
    remaining -= batch.length
  }
  console.log(`Imported ${imported} of ${events.length}...`)
}

// %% [markdown]
// ### Birth

// %%
const events: Array<CrvsEvent> = []

console.log('Processing birth events...')
csvData.birth
  .filter((x) => x.BIRTH_REF)
  .forEach((birth) => {
    const declaration: Partial<Record<keyof BirthResolver, any>> = {}

    Object.entries(birthResolver).forEach(([eventField, dataField]) => {
      if (typeof dataField === 'function') {
        const data = dataField(birth, csvData, updatedLocationsMap)
        declaration[eventField as keyof BirthResolver] = data
      }
    })

    const meta: Partial<Record<keyof typeof birthMetaData, any>> = {}
    Object.entries(birthMetaData).forEach(([metaField, dataField]) => {
      const data = dataField(birth, csvData, updatedLocationsMap)
      meta[metaField as keyof BirthMetaData] = data
    })

    const locationId = locationCodes.find(
      (loc: any) => loc.code === meta.locationCode
    )?.id

    const event = transform(
      nonNullObjectKeys(declaration),
      'birth',
      meta.registrationDate || new Date().toISOString(),
      user,
      role,
      locationId || centralLocationId,
      birth.BIRTH_REF,
      toLegacy(birth.BIRTH_REF, 'birth')
    )

    events.push(event)

    const nameChanges = csvData.deedpoll
      .filter(
        (deed) => deed.BIRTH_REF.toUpperCase() === birth.BIRTH_REF.toUpperCase()
      )
      .sort(
        (a, b) =>
          new Date(toCrvsDate(a.DATE) as string).getTime() -
          new Date(toCrvsDate(b.DATE) as string).getTime()
      )
    if (nameChanges.length > 0) {
      const nameChangeDeclaration: Partial<
        Record<keyof NameChangeResolver, any>
      > = {}

      nameChanges.forEach((nc) => {
        Object.entries(nameChangeResolver).forEach(
          ([eventField, dataField]) => {
            if (typeof dataField === 'function') {
              const data = dataField(
                nc,
                birth,
                nameChanges,
                updatedLocationsMap
              )
              nameChangeDeclaration[eventField as keyof NameChangeResolver] =
                data
            }
          }
        )

        const changeEvent = transform(
          nonNullObjectKeys(nameChangeDeclaration),
          'name-change',
          meta.registrationDate || new Date().toISOString(),
          user,
          role,
          locationId || centralLocationId,
          birth.BIRTH_REF,
          toLegacy(nc.DP_REF, 'name-change')
        )
        events.push(changeEvent)
      })
    }
  })

await writeTrackingIdsToFile()
console.log('Finished processing birth events.')

await migrateEvents(events, 'birth')

// %% [markdown]
// ### Death

// %%
const deathEvents: Array<CrvsEvent> = []

csvData.death
  .filter((x) => x.DEATH_NUMBER)
  .forEach((death) => {
    const declaration: Partial<Record<keyof DeathResolver, any>> = {}

    Object.entries(deathResolver).forEach(([eventField, dataField]) => {
      if (typeof dataField === 'function') {
        const data = dataField(death, csvData, updatedLocationsMap)
        declaration[eventField as keyof DeathResolver] = data
      }
    })

    const meta: Partial<Record<keyof typeof deathMetaData, any>> = {}
    Object.entries(deathMetaData).forEach(([metaField, dataField]) => {
      const data = dataField(death, csvData, updatedLocationsMap)
      meta[metaField as keyof typeof deathMetaData] = data
    })

    const locationId = locationCodes.find(
      (loc: any) => loc.code === meta.locationCode
    )?.id

    const event = transform(
      nonNullObjectKeys(declaration),
      'death',
      meta.registrationDate || new Date().toISOString(),
      user,
      role,
      locationId,
      death.DEATH_NUMBER,
      toLegacy(death.DEATH_NUMBER, 'death')
    )

    deathEvents.push(event)
  })
await writeTrackingIdsToFile()
await migrateEvents(deathEvents, 'death')

// %% [markdown]
// ### Marriage

// %%
const marriageEvents: Array<CrvsEvent> = []

csvData.marriage
  .filter((x) => x.NOTICE_NUMBER)
  .forEach((marriage) => {
    const declaration: Partial<Record<keyof MarriageResolver, any>> = {}

    Object.entries(marriageResolver).forEach(([eventField, dataField]) => {
      if (typeof dataField === 'function') {
        const data = dataField(marriage, csvData, updatedLocationsMap)
        declaration[eventField as keyof MarriageResolver] = data
      }
    })

    const meta: Partial<Record<keyof typeof marriageMetaData, any>> = {}
    Object.entries(marriageMetaData).forEach(([metaField, dataField]) => {
      const data = dataField(marriage, csvData, updatedLocationsMap)
      meta[metaField as keyof typeof marriageMetaData] = data
    })

    const locationId = locationCodes.find(
      (loc: any) => loc.code === meta.locationCode
    )?.id

    const event = transform(
      nonNullObjectKeys(declaration),
      'marriage-registration',
      meta.registrationDate || new Date().toISOString(),
      user,
      role,
      locationId,
      marriage.NOTICE_NUMBER,
      toLegacy(marriage.NOTICE_NUMBER, 'marriage-registration')
    )

    marriageEvents.push(event)
  })
await writeTrackingIdsToFile()
await migrateEvents(marriageEvents, 'marriage-registration')

// %% [markdown]
// ### Adoption

// %%
import { AdoptionResolver } from './helpers/adoptionTypes.ts'
import {
  adoptionResolver,
  adoptionMetaData
} from './mappings/adoptionResolver.ts'
import type { AdoptionCsvRecord, BirthCsvRecord } from './helpers/csvTypes.ts'

const adoptionEvents: Array<CrvsEvent> = []

function mapAdoptionToBirth(
  adoption: AdoptionCsvRecord
): Partial<BirthCsvRecord> {
  const { ADOPTION_REF, ACT, ...shared } = adoption
  return {
    ...shared,
    ADOP_REC_REF: ADOPTION_REF,
    BIRTH_REF: toLegacy(ADOPTION_REF, 'birth') // Assuming the birth record uses the same reference as the adoption record
  }
}

csvData.adoption.forEach((adoption) => {
  const declaration: Partial<Record<keyof AdoptionResolver, any>> = {}

  Object.entries(adoptionResolver).forEach(([eventField, dataField]) => {
    if (typeof dataField === 'function') {
      const data = dataField(adoption, csvData, updatedLocationsMap)
      declaration[eventField as keyof AdoptionResolver] = data
    }
  })

  const meta: Partial<Record<keyof typeof adoptionMetaData, any>> = {}
  Object.entries(adoptionMetaData).forEach(([metaField, dataField]) => {
    const data = dataField(adoption, csvData, updatedLocationsMap)
    meta[metaField as keyof typeof adoptionMetaData] = data
  })

  const locationId = locationCodes.find(
    (loc: any) => loc.code === meta.locationCode
  )?.id

  const event = transform(
    nonNullObjectKeys(declaration),
    'adoption',
    meta.registrationDate || new Date().toISOString(),
    user,
    role,
    locationId,
    adoption.ADOPTION_REF,
    toLegacy(adoption.ADOPTION_REF, 'adoption')
  )

  adoptionEvents.push(event)

  const birth = mapAdoptionToBirth(adoption)
  const birthDeclaration: Partial<Record<keyof BirthResolver, any>> = {}

  Object.entries(birthResolver).forEach(([eventField, dataField]) => {
    if (typeof dataField === 'function') {
      const data = dataField(
        birth as BirthCsvRecord,
        csvData,
        updatedLocationsMap
      )
      birthDeclaration[eventField as keyof BirthResolver] = data
    }
  })

  const birthEvent = transform(
    nonNullObjectKeys(birthDeclaration),
    'birth',
    meta.registrationDate || new Date().toISOString(),
    user,
    role,
    locationId || centralLocationId,
    birth.BIRTH_REF!,
    toLegacy(adoption.ADOPTION_REF, 'birth')
  )
  adoptionEvents.push(birthEvent)
})
await writeTrackingIdsToFile()
await migrateEvents(adoptionEvents, 'adoption')

// %% [markdown]
// ### Divorce

// %%
import { DivorceResolver } from './helpers/divorceTypes.ts'
import { divorceResolver, divorceMetaData } from './mappings/divorceResolver.ts'

const divorceEvents: Array<CrvsEvent> = []

csvData.marriage
  .filter((x) => x.Dissolved === 'TRUE')
  .forEach((divorce) => {
    const declaration: Partial<Record<keyof DivorceResolver, any>> = {}

    Object.entries(divorceResolver).forEach(([eventField, dataField]) => {
      if (typeof dataField === 'function') {
        const data = dataField(divorce, csvData, updatedLocationsMap)
        declaration[eventField as keyof DivorceResolver] = data
      }
    })

    const meta: Partial<Record<keyof typeof divorceMetaData, any>> = {}
    Object.entries(divorceMetaData).forEach(([metaField, dataField]) => {
      const data = dataField(divorce, csvData, updatedLocationsMap)
      meta[metaField as keyof typeof divorceMetaData] = data
    })

    const locationId = locationCodes.find(
      (loc: any) => loc.code === meta.locationCode
    )?.id

    const event = transform(
      nonNullObjectKeys(declaration),
      'divorce',
      meta.registrationDate || new Date().toISOString(),
      user,
      role,
      locationId,
      divorce.NOTICE_NUMBER,
      toLegacy(divorce.NOTICE_NUMBER, 'divorce')
    )

    divorceEvents.push(event)
  })
await writeTrackingIdsToFile()
await migrateEvents(divorceEvents, 'divorce')

// %% [markdown]
// ### Reindex

// %%
import { reindex } from '../v1-to-v2-data-migration/helpers/gqlHandlers.ts'

console.log('Reindexing....')
const reindexResponse = await reindex(sysToken)
reindexResponse

// %% [markdown]
// ### Output results

// %%
console.log('🍞 Declarations succesfully migrated')
