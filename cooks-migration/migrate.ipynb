// %% [markdown]
// ### Authenticate
// Get the client id and secret from env vars for prod.
// In dev we can create a new client each time

// %%
import { registerSystem } from '../v1-to-v2-data-migration/helpers/gqlHandlers.ts'
import { authenticate, getTokenForSystemClient } from '../v1-to-v2-data-migration/helpers/authentication.ts'
import { CLIENT_ID, CLIENT_SECRET } from '../v1-to-v2-data-migration/helpers/vars.ts'
import { ADMIN_USERNAME, ADMIN_PASSWORD } from '../v1-to-v2-data-migration/helpers/vars.ts'


let clientId: string | null = null
let clientSecret: string | null = null

if (CLIENT_ID && CLIENT_SECRET) {
  clientId = CLIENT_ID
  clientSecret = CLIENT_SECRET
} else {
  // For dev mode
  const adminToken = await authenticate(ADMIN_USERNAME, ADMIN_PASSWORD)
  const systemRegistration = await registerSystem(adminToken)

  clientId = systemRegistration.data.registerSystem.system.clientId
  clientSecret = systemRegistration.data.registerSystem.clientSecret
}

const sysToken = await getTokenForSystemClient(clientId, clientSecret)
sysToken
// Out:
// "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....Weo5JW6pBRtZDKvLmkc20gPwVWxhQKVJsSQJwMhmvb-q1EXwDB-BUPs3EH5xT1A1WJQziCj5OjkR0s1V2DPwrNipzVwIFf2FTmAxpUe4r_a9bQlHPQzwprreO1yrjer2rxmtm_a_V1pdpik3TjLUXy1PXEUhb4cDDAvKo2fKQNFis-D0nogKK0qBJs_HJ6tbZRnEsxVEfLm49uiGduH_VMNkupB_W0lgpJiqtYocrIMpxptwB_BMx-ktpt_iRBbnH7RM5EPLAAiivhBpLV-urY88AdYS8w2PiUQxkr_lZchI2LXlMJb7a97oUO2MwMLU94d3N-KTqUPLa3Fqnt1_aA"

// %% [markdown]
// ### Fetch data from CSVs

// %%
import { csvToJson } from './helpers/csvHelpers.ts'
import { CsvFields } from "./helpers/csvTypes.ts";

const pathToBirthCsv = './sourceData/Birth_Register.csv'
const pathToDeathCsv = './sourceData/Death_Register.csv'
const pathToMarriageCsv = './sourceData/Marriage_Register.csv'
const pathToAdoptionCsv = './sourceData/Adoption_Register.csv'
const pathToDeedpollCsv = './sourceData/Deedpoll.csv'

const csvData: CsvFields = {
  birth: await csvToJson(pathToBirthCsv),
  death: await csvToJson(pathToDeathCsv),
  marriage: await csvToJson(pathToMarriageCsv),
  adoption: await csvToJson(pathToAdoptionCsv),
  deedpoll: await csvToJson(pathToDeedpollCsv),
}

// %%
import { GATEWAY } from '../v1-to-v2-data-migration/helpers/routes.ts'
import { locationsMap } from './lookupMappings/locations.ts'

export const getLocations = async (
  token: string,
  type: 'ADMIN_STRUCTURE' | 'HEALTH_FACILITY',
) => {
  const response = await fetch(
    `${GATEWAY}/location?type=${type}&_count=0&status=active`,
    {
      method: 'GET',
      headers: {
        'Content-Type': 'application/json',
        Authorization: `Bearer ${token}`,
      },
    },
  )
  if (!response.ok) {
    throw new Error(`Sync Locations failed: ${response.statusText}`)
  }
  return response
}

const locationsRes = await getLocations(sysToken, 'ADMIN_STRUCTURE')
const healthFacilitiesRes = await getLocations(sysToken, 'HEALTH_FACILITY')
const fhirLocations = await locationsRes.json()
const fhirHealthFacilities = await healthFacilitiesRes.json()
const locationCodes = fhirLocations.entry
  .concat(fhirHealthFacilities.entry)
  .map((loc: any) => ({
    id: loc.resource.id,
    name: loc.resource.name,
    code:
      loc.resource.identifier[0]?.value
        .replace('ADMIN_STRUCTURE_', '')
        .replace('HEALTH_FACILITY_', '') || null,
  }))


const updatedLocationsMap = locationsMap.map((loc: any) => ({
  ...loc,
  id: locationCodes.find((l: any) => l.code === loc.map)?.id || null,
}))
updatedLocationsMap
// Out:
// [
//   {
//     name: '"MV AKATERE" EN ROUTE TO PUKAPUKA',
//     map: "COK-011",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "d878d78b-68a9-4bb4-b713-f88229df04bc"
//   },
//   {
//     name: '"TAVEUNI" AT SEA',
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: '"TAVEUNI"',
//     id: null
//   },
//   {
//     name: "''TIARE TAPORO'' AT SEA",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "''TIARE TAPORO''",
//     id: null
//   },
//   {
//     name: "(1) MAKATEA ISLAND (2) FRENCH OCEANIA",
//     map: null,
//     facilityCode: null,
//     country: "ALA",
//     intlTown: "(1) MAKATEA",
//     id: null
//   },
//   {
//     name: "(AT WAR)",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: ",ITIARO",
//     map: "COK-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "c1ed5f99-531d-49dc-a855-bd81208cc88d"
//   },
//   {
//     name: ",MANGAIA",
//     map: "COK-006",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "be59cbbd-a21f-42d6-b9f3-d1397e9e302f"
//   },
//   {
//     name: "-",
//     map: "COK-001-001-001",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "8003482e-0337-48c4-849d-6274abea3aee"
//   },
//   {
//     name: "---------------",
//     map: "COK-001-001-001",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "8003482e-0337-48c4-849d-6274abea3aee"
//   },
//   {
//     name: ".ARORANGI,RAROTONGA",
//     map: "COK-001-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "f4564ea0-7855-4121-9892-42be86bb48cf"
//   },
//   {
//     name: "0",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "00000000000000000000000000000000000000000000000000",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "1",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "14 JOHN STREET TOKOROA",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "17 NZ",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "1978",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "2 GUNSON ST PONSONBY",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "21/6/1931",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "23/11/1908",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "25 ESKI AVENUE TOKOROA NEW ZEALAND",
//     map: null,
//     facilityCode: null,
//     country: "NZL",
//     intlTown: "ESKI AVENUE TOKOROA",
//     id: null
//   },
//   {
//     name: "42 HOME STREET GREY LYNN AUCKLAND",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "43 COWAN ST PONSONBY AUCKLAND NEW ZEALAND",
//     map: null,
//     facilityCode: null,
//     country: "NZL",
//     intlTown: "COWAN ST PONSONBY AUCKLAND",
//     id: null
//   },
//   {
//     name: "5",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "5 CAMPDALE PLACE, ORANGE 2800, N.S.W, AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "CAMPDALE PLACE, ORANGE 2800, N.",
//     id: null
//   },
//   {
//     name: "63.PP",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "67 KING ST KINGSLAND",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "8 PRINCESS ST MARTON",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "8/5/1945",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "9 THOMPSON STREET, MANGERE EAST AUCKLAND NZ",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: ";MATAVERA RAROTONGA",
//     map: "COK-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "ec93af52-275a-40f7-aea5-2db4c7ff789e"
//   },
//   {
//     name: "AACHEN GERMANY",
//     map: null,
//     facilityCode: null,
//     country: "DEU",
//     intlTown: "AACHEN",
//     id: null
//   },
//   {
//     name: "AARORANGI RAROTONGA",
//     map: "COK-001-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "f4564ea0-7855-4121-9892-42be86bb48cf"
//   },
//   {
//     name: "AARORANGI TUPAPA RAROTONGA",
//     map: "COK-001-001-001",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "8003482e-0337-48c4-849d-6274abea3aee"
//   },
//   {
//     name: "AATIU, RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "fc5fbca2-1b5e-49d6-8a44-14a6b499c67c"
//   },
//   {
//     name: "ABAIANG, KIRIBATI",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "ABAIANG",
//     id: null
//   },
//   {
//     name: "ABATIU RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "fc5fbca2-1b5e-49d6-8a44-14a6b499c67c"
//   },
//   {
//     name: "ABEMAMA KIRIBATI",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "ABEMAMA",
//     id: null
//   },
//   {
//     name: "ABERDEEN SCOTLAND",
//     map: null,
//     facilityCode: null,
//     country: "GBR",
//     intlTown: "ABERDEEN",
//     id: null
//   },
//   {
//     name: "ABIANG KIRIBATI",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "ABIANG",
//     id: null
//   },
//   {
//     name: "ABIANG, KIRIBATI",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "ABIANG",
//     id: null
//   },
//   {
//     name: "ABOARD THE MV BODMER",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "ABUYOG LEYTE, PHILLIPINE",
//     map: null,
//     facilityCode: null,
//     country: "PHL",
//     intlTown: "ABUYOG LEYTE",
//     id: null
//   },
//   {
//     name: "ACKLAND NEW ZEALAND",
//     map: null,
//     facilityCode: null,
//     country: "NZL",
//     intlTown: "ACKLAND",
//     id: null
//   },
//   {
//     name: "ADELAIDE AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "ADELAIDE",
//     id: null
//   },
//   {
//     name: "ADELAIDE SOUTH AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "ADELAIDE SOUTH",
//     id: null
//   },
//   {
//     name: "ADELAIDE, AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "ADELAIDE",
//     id: null
//   },
//   {
//     name: "ADELAIDE, SOUTH AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "ADELAIDE, SOUTH",
//     id: null
//   },
//   {
//     name: "AEORA ATIU",
//     map: "COK-003-001-001",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "692f29fd-4681-41b3-9489-0a8c5f6d609d"
//   },
//   {
//     name: "AEORA MAUKE",
//     map: "COK-004",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "a4388688-56c0-45f4-a603-bebface53e45"
//   },
//   {
//     name: "AERENGA ARORANGI",
//     map: "COK-001-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "f4564ea0-7855-4121-9892-42be86bb48cf"
//   },
//   {
//     name: "AERENGAMATE",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AERODROME RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "fc5fbca2-1b5e-49d6-8a44-14a6b499c67c"
//   },
//   {
//     name: "AERORA",
//     map: "COK-001-006-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "3ff799a3-f4b3-4872-8bef-e6fa3b1bcafc"
//   },
//   {
//     name: "AFAAHITI, TAHITI",
//     map: null,
//     facilityCode: null,
//     country: "PYF",
//     intlTown: "AFAAHITI",
//     id: null
//   },
//   {
//     name: "AFEGA, SAMOA",
//     map: null,
//     facilityCode: null,
//     country: "WSM",
//     intlTown: "AFEGA",
//     id: null
//   },
//   {
//     name: "AGRICULTURE LABOURER",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AGRICULTURE STOREMAN",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AIPAE",
//     map: "COK-002-001-007",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "475d6902-7ef5-4e2a-a376-95778c46d981"
//   },
//   {
//     name: "AIRPORT",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AIRPORT AITUTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AISTRALIA",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AITU",
//     map: "COK-002-001-008",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "712a18ae-cfba-4ae8-9f32-84f47aa6dffd"
//   },
//   {
//     name: "AITUAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUATAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUATKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAK",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKI (DECEASED)",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKI AITUTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKI ARUTANGA",
//     map: "COK-002-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "2e104e21-3a98-4af2-8339-31e26ef452f5"
//   },
//   {
//     name: "AITUTAKI COOK ISLAND",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKI COOK ISLANDS",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKI COOK ISLANS",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKI RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "fc5fbca2-1b5e-49d6-8a44-14a6b499c67c"
//   },
//   {
//     name: "AITUTAKI, COOK ISLANDER",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKI, COOK ISLANDS",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTAKU",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUTKAI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUYAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AITUYTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AIU",
//     map: "COK-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "c7cf7be6-ac5c-4351-83e2-86250100ab1d"
//   },
//   {
//     name: "AIUTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "af2a188a-9145-4646-8165-80ef8c83e268"
//   },
//   {
//     name: "AKAIAMI  TAUTU AITUTAKI",
//     map: "COK-002-001-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0ad3523f-4394-4f4b-8351-5a9e85b8cde5"
//   },
//   {
//     name: "AKAOA",
//     map: "COK-001-005-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "03fe78e8-5984-4ee4-b351-e83a84ac011b"
//   },
//   {
//     name: "AKAOA ARORANGI",
//     map: "COK-001-005-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "03fe78e8-5984-4ee4-b351-e83a84ac011b"
//   },
//   {
//     name: "AKAOA ARORANGI RAROTONGA",
//     map: "COK-001-005-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "03fe78e8-5984-4ee4-b351-e83a84ac011b"
//   },
//   {
//     name: "AKAOA, ARORANGI, RAROTONGA",
//     map: "COK-001-005-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "03fe78e8-5984-4ee4-b351-e83a84ac011b"
//   },
//   {
//     name: "AKIRKBY DENMARK",
//     map: null,
//     facilityCode: null,
//     country: "DNK",
//     intlTown: "AKIRKBY",
//     id: null
//   },
//   {
//     name: "AKIRKEBY, DENMARK",
//     map: null,
//     facilityCode: null,
//     country: "DNK",
//     intlTown: "AKIRKEBY",
//     id: null
//   },
//   {
//     name: "AKUVAINE RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "fc5fbca2-1b5e-49d6-8a44-14a6b499c67c"
//   },
//   {
//     name: "ALGERIA AFRICA",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "ALGERIA, AFRICA",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "ALMERE, NEDERLANDSE",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "ALOFI NIUE",
//     map: null,
//     facilityCode: null,
//     country: "NIU",
//     intlTown: "ALOFI",
//     id: null
//   },
//   {
//     name: "ALOFI, NIUE",
//     map: null,
//     facilityCode: null,
//     country: "NIU",
//     intlTown: "ALOFI",
//     id: null
//   },
//   {
//     name: "ALOGI NIUE",
//     map: null,
//     facilityCode: null,
//     country: "NIU",
//     intlTown: "ALOGI",
//     id: null
//   },
//   {
//     name: "AMANAIA",
//     map: "COK-006",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "be59cbbd-a21f-42d6-b9f3-d1397e9e302f"
//   },
//   {
//     name: "AMANAIA PUKAPUKA",
//     map: "COK-011",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "d878d78b-68a9-4bb4-b713-f88229df04bc"
//   },
//   {
//     name: "AMANIA PUKAPUKA",
//     map: "COK-011",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "d878d78b-68a9-4bb4-b713-f88229df04bc"
//   },
//   {
//     name: "AMBULANCE EN ROUTE TO HOSPITAL, RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "fc5fbca2-1b5e-49d6-8a44-14a6b499c67c"
//   },
//   ... 4532 more items
// ]

// %% [markdown]
// ### Get all potential resolvers
// Use only resolvers for used event fields to avoid nulls

// %%
import { birthResolver, birthMetaData } from './mappings/birthResolver.ts'
import { transform } from './helpers/transform.ts'
import { bulkImport } from '../v1-to-v2-data-migration/helpers/gqlHandlers.ts'
import {
  batch,
  getIndexErrors,
} from '../v1-to-v2-data-migration/helpers/utils.ts'
import { generateRegistrationNumber } from './helpers/generators.ts'
import { CrvsEvent } from './helpers/types.ts'
import { BirthResolver } from './helpers/birthTypes.ts'
import { toCrvsDate } from './helpers/resolverHelpers.ts'
import { nameChangeResolver } from './mappings/nameChangeResolver.ts'

function nonNullObjectKeys(obj: Record<string, any>) {
  return Object.fromEntries(
    Object.entries(obj).filter(
      ([_, value]) => value !== null && value !== undefined && value !== '',
    ),
  )
}

const events: Array<CrvsEvent> = []

csvData.birth.forEach((birth) => {
  const declaration: Partial<Record<keyof typeof birthResolver, any>> = {}
  Object.entries(birthResolver).forEach(([eventField, dataField]) => {
    if (typeof dataField === 'function') {
      const data = dataField(birth, csvData, updatedLocationsMap)
      declaration[eventField as keyof typeof birthResolver] = data
    }
  })

  const meta: Partial<Record<keyof typeof birthMetaData, any>> = {}
  Object.entries(birthMetaData).forEach(([metaField, dataField]) => {
    const data = dataField(birth, csvData, updatedLocationsMap)
    meta[metaField as keyof typeof birthMetaData] = data
  })

  const user = 'f686c526-c6b5-41ed-b3cc-43b104fa5c03'
  //const location = '08260e22-bb67-4702-8760-86ec125e1079'
  const role = 'REGISTRAR' // Probably ok to hardcode this

  const locationId = locationCodes.find(
    (loc: any) => loc.code === meta.locationCode,
  )?.id

  const event = transform(
    nonNullObjectKeys(declaration),
    'birth',
    meta.registrationDate || new Date().toISOString(),
    user, //TODO change to lookup meta.registrar,
    role,
    locationId,
    birth.BIRTH_REF,
    birth.BIRTH_REF,
    // generateRegistrationNumber(
    //   meta.locationCode || '',
    //   meta.registrationDate || new Date().toISOString(),
    //   'birth',
    // ),
  )

  //events.push(event)

  const nameChanges = csvData.deedpoll
    .filter(
      (deed) => deed.BIRTH_REF.toUpperCase() === birth.BIRTH_REF.toUpperCase(),
    )
    .sort(
      (a, b) =>
        new Date(toCrvsDate(a.DATE)).getTime() -
        new Date(toCrvsDate(b.DATE)).getTime(),
    )
  if (nameChanges.length > 0) {
    const nameChangeDeclaration = {}
    nameChanges.forEach((nc) => {
      Object.entries(nameChangeResolver).forEach(([eventField, dataField]) => {
        if (dataField) {
          const data = dataField(nc, birth, nameChanges)
          nameChangeDeclaration[eventField] = data
        }
      })

      const changeEvent = transform(
        nonNullObjectKeys(nameChangeDeclaration),
        'name-change',
        meta.registrationDate || new Date().toISOString(),
        user, //TODO change to lookup meta.registrar,
        role,
        locationId,
        birth.BIRTH_REF,
        birth.BIRTH_REF+nc.DP_REF,
        // generateRegistrationNumber(
        //   meta.locationCode || '',
        //   meta.registrationDate || new Date().toISOString(),
        //   'birth',
        // ),
      )
      events.push(changeEvent)
    })
  }
})

const batches = batch(events, 1000)

for (const batch of [batches[0]]) {
  const res = await bulkImport(batch, sysToken)
  console.log(res)
  const errors = getIndexErrors(res)
  if (errors) {
    console.error('Errors during bulk import', errors)
  }
}
// Out:
// {
//   result: {
//     data: {
//       json: {
//         errors: true,
//         took: 200,
//         items: [
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object], [Object], [Object],
//           [Object], [Object], [Object], [Object],
//           ... 240 more items
//         ]
//       }
//     }
//   }
// }
// Errors during bulk import [
//   "[1:996] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:974] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:967] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1082] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1082] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:954] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1061] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:982] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1072] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1104] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1159] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:963] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1046] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:986] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:984] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:962] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:976] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:950] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1006] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:973] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:983] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1006] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:984] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1099] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:956] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:987] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1016] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1114] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:977] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:977] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:986] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:984] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1082] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1081] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1137] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1137] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1191] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1057] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:996] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1082] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1225] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:976] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1051] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:987] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:997] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:968] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1036] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:964] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1115] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1057] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:996] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1035] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1104] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:970] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1087] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1179] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1280] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1006] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1137] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:997] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1004] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1016] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:963] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:974] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:976] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1170] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:995] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1004] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:994] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1004] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1255] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1269] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:984] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1017] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:993] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:996] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:975] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1030] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:993] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1126] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:955] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1159] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1093] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:990] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1148] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1077] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1006] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1015] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1016] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1137] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:970] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1027] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1006] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1225] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1003] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:998] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1024] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1060] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:1215] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   "[1:956] object mapping for [declaration.witness____address] tried to parse field [witness____address] as object, but found a concrete value",
//   ... 239 more items
// ]

// %%
import { reindex } from "../v1-to-v2-data-migration/helpers/gqlHandlers.ts";

const reindexResponse = await reindex(sysToken);
reindexResponse
// Out:
// "OK"

// %% [markdown]
// ### Output results

// %%
console.log('🍞 Declarations succesfully migrated')
// Out:
// 🍞 Declarations succesfully migrated
