// %% [markdown]
// ### Authenticate
// Get the client id and secret from env vars for prod.
// In dev we can create a new client each time

// %%
import { registerSystem } from '../v1-to-v2-data-migration/helpers/gqlHandlers.ts'
import { authenticate, getTokenForSystemClient } from '../v1-to-v2-data-migration/helpers/authentication.ts'
import { CLIENT_ID, CLIENT_SECRET } from '../v1-to-v2-data-migration/helpers/vars.ts'
import { ADMIN_USERNAME, ADMIN_PASSWORD } from '../v1-to-v2-data-migration/helpers/vars.ts'


let clientId: string | null = null
let clientSecret: string | null = null

if (CLIENT_ID && CLIENT_SECRET) {
  clientId = CLIENT_ID
  clientSecret = CLIENT_SECRET
} else {
  // For dev mode
  const adminToken = await authenticate(ADMIN_USERNAME, ADMIN_PASSWORD)
  const systemRegistration = await registerSystem(adminToken)

  clientId = systemRegistration.data.registerSystem.system.clientId
  clientSecret = systemRegistration.data.registerSystem.clientSecret
}

const sysToken = await getTokenForSystemClient(clientId, clientSecret)
sysToken
// Out:
// "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....0jEWFvbszl6xJEFQpxCjD3IPqPCcE7TrAIt5Fq9HdgiHGC-Jp89BN7761qSakrKCkxNxA-5Y2V0csd0B_BaFcybtMyDiTKF7hJL0Ns9xVjE_UVTgRP1DQPJ50t79Sib6W4lJacxyq7bY8029v-88ic9lYLjQ6UB9y0eb7c8F-3TNrDsi03zHS7nB0nGewTL0TRBKzAUiLaEXlPWwYSBXQv8TENOCUfMkSt5WYN7UvO4M8f8o6U5MPogt7JRS_k9mUCK2QZzi09nGJjhfTmUlYD5b27DtmJf0Fx7adJTesXImp8m1mMz5DfzEnC5bb8Z8nIHZTdXP0fjXLxLPSvWxzA"

// %% [markdown]
// ### Fetch data from CSVs

// %%
import { csvToJson } from './helpers/csvHelpers.ts'
import { CsvFields } from "./helpers/csvTypes.ts";

const pathToBirthCsv = './sourceData/Birth_Register.csv'
const pathToDeathCsv = './sourceData/Death_Register.csv'
const pathToMarriageCsv = './sourceData/Marriage_Register.csv'
const pathToAdoptionCsv = './sourceData/Adoption_Register.csv'
const pathToDeedpollCsv = './sourceData/Deedpoll.csv'

const csvData: CsvFields = {
  birth: await csvToJson(pathToBirthCsv),
  death: await csvToJson(pathToDeathCsv),
  marriage: await csvToJson(pathToMarriageCsv),
  adoption: await csvToJson(pathToAdoptionCsv),
  deedpoll: await csvToJson(pathToDeedpollCsv),
}

// %%
import { GATEWAY } from '../v1-to-v2-data-migration/helpers/routes.ts'
import { locationsMap } from './lookupMappings/locations.ts'

export const getLocations = async (
  token: string,
  type: 'ADMIN_STRUCTURE' | 'HEALTH_FACILITY',
) => {
  const response = await fetch(
    `${GATEWAY}/location?type=${type}&_count=0&status=active`,
    {
      method: 'GET',
      headers: {
        'Content-Type': 'application/json',
        Authorization: `Bearer ${token}`,
      },
    },
  )
  if (!response.ok) {
    throw new Error(`Sync Locations failed: ${response.statusText}`)
  }
  return response
}

const locationsRes = await getLocations(sysToken, 'ADMIN_STRUCTURE')
const healthFacilitiesRes = await getLocations(sysToken, 'HEALTH_FACILITY')
const fhirLocations = await locationsRes.json()
const fhirHealthFacilities = await healthFacilitiesRes.json()
const locationCodes = fhirLocations.entry
  .concat(fhirHealthFacilities.entry)
  .map((loc: any) => ({
    id: loc.resource.id,
    name: loc.resource.name,
    code:
      loc.resource.identifier[0]?.value
        .replace('ADMIN_STRUCTURE_', '')
        .replace('HEALTH_FACILITY_', '') || null,
  }))


const updatedLocationsMap = locationsMap.map((loc: any) => ({
  ...loc,
  id: locationCodes.find((l: any) => l.code === loc.map)?.id || null,
}))
updatedLocationsMap
// Out:
// [
//   {
//     name: '"MV AKATERE" EN ROUTE TO PUKAPUKA',
//     map: "COK-011",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "4effa0c9-6e48-4cb9-92a0-72646e9acff7"
//   },
//   {
//     name: '"TAVEUNI" AT SEA',
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: '"TAVEUNI"',
//     id: null
//   },
//   {
//     name: "''TIARE TAPORO'' AT SEA",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "''TIARE TAPORO''",
//     id: null
//   },
//   {
//     name: "(1) MAKATEA ISLAND (2) FRENCH OCEANIA",
//     map: null,
//     facilityCode: null,
//     country: "ALA",
//     intlTown: "(1) MAKATEA",
//     id: null
//   },
//   {
//     name: "(AT WAR)",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: ",ITIARO",
//     map: "COK-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "1024f04a-e590-4708-8340-b8a0be322857"
//   },
//   {
//     name: ",MANGAIA",
//     map: "COK-006",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "d49d39c8-a544-440a-95ff-1500274726f5"
//   },
//   {
//     name: "-",
//     map: "COK-001-001-001",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "dccd79ce-7dda-4f6e-aff8-b15eb30f1f02"
//   },
//   {
//     name: "---------------",
//     map: "COK-001-001-001",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "dccd79ce-7dda-4f6e-aff8-b15eb30f1f02"
//   },
//   {
//     name: ".ARORANGI,RAROTONGA",
//     map: "COK-001-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "1b498318-1ccb-48fa-be16-58a80af3bd56"
//   },
//   {
//     name: "0",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "00000000000000000000000000000000000000000000000000",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "1",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "14 JOHN STREET TOKOROA",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "17 NZ",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "1978",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "2 GUNSON ST PONSONBY",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "21/6/1931",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "23/11/1908",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "25 ESKI AVENUE TOKOROA NEW ZEALAND",
//     map: null,
//     facilityCode: null,
//     country: "NZL",
//     intlTown: "ESKI AVENUE TOKOROA",
//     id: null
//   },
//   {
//     name: "42 HOME STREET GREY LYNN AUCKLAND",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "43 COWAN ST PONSONBY AUCKLAND NEW ZEALAND",
//     map: null,
//     facilityCode: null,
//     country: "NZL",
//     intlTown: "COWAN ST PONSONBY AUCKLAND",
//     id: null
//   },
//   {
//     name: "5",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "5 CAMPDALE PLACE, ORANGE 2800, N.S.W, AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "CAMPDALE PLACE, ORANGE 2800, N.",
//     id: null
//   },
//   {
//     name: "63.PP",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "67 KING ST KINGSLAND",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "8 PRINCESS ST MARTON",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "8/5/1945",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "9 THOMPSON STREET, MANGERE EAST AUCKLAND NZ",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: ";MATAVERA RAROTONGA",
//     map: "COK-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "2a65130a-3588-4943-a360-82f21b7c417e"
//   },
//   {
//     name: "AACHEN GERMANY",
//     map: null,
//     facilityCode: null,
//     country: "DEU",
//     intlTown: "AACHEN",
//     id: null
//   },
//   {
//     name: "AARORANGI RAROTONGA",
//     map: "COK-001-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "1b498318-1ccb-48fa-be16-58a80af3bd56"
//   },
//   {
//     name: "AARORANGI TUPAPA RAROTONGA",
//     map: "COK-001-001-001",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "dccd79ce-7dda-4f6e-aff8-b15eb30f1f02"
//   },
//   {
//     name: "AATIU, RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "e289b9bc-23e1-45b1-ac4e-ce3694832b99"
//   },
//   {
//     name: "ABAIANG, KIRIBATI",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "ABAIANG",
//     id: null
//   },
//   {
//     name: "ABATIU RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "e289b9bc-23e1-45b1-ac4e-ce3694832b99"
//   },
//   {
//     name: "ABEMAMA KIRIBATI",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "ABEMAMA",
//     id: null
//   },
//   {
//     name: "ABERDEEN SCOTLAND",
//     map: null,
//     facilityCode: null,
//     country: "GBR",
//     intlTown: "ABERDEEN",
//     id: null
//   },
//   {
//     name: "ABIANG KIRIBATI",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "ABIANG",
//     id: null
//   },
//   {
//     name: "ABIANG, KIRIBATI",
//     map: null,
//     facilityCode: null,
//     country: "KIR",
//     intlTown: "ABIANG",
//     id: null
//   },
//   {
//     name: "ABOARD THE MV BODMER",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "ABUYOG LEYTE, PHILLIPINE",
//     map: null,
//     facilityCode: null,
//     country: "PHL",
//     intlTown: "ABUYOG LEYTE",
//     id: null
//   },
//   {
//     name: "ACKLAND NEW ZEALAND",
//     map: null,
//     facilityCode: null,
//     country: "NZL",
//     intlTown: "ACKLAND",
//     id: null
//   },
//   {
//     name: "ADELAIDE AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "ADELAIDE",
//     id: null
//   },
//   {
//     name: "ADELAIDE SOUTH AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "ADELAIDE SOUTH",
//     id: null
//   },
//   {
//     name: "ADELAIDE, AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "ADELAIDE",
//     id: null
//   },
//   {
//     name: "ADELAIDE, SOUTH AUSTRALIA",
//     map: null,
//     facilityCode: null,
//     country: "AUS",
//     intlTown: "ADELAIDE, SOUTH",
//     id: null
//   },
//   {
//     name: "AEORA ATIU",
//     map: "COK-003-001-001",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "58139d65-c8dd-495d-b701-85e16e05e343"
//   },
//   {
//     name: "AEORA MAUKE",
//     map: "COK-004",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "15337d68-89cb-4b1f-afcf-0c4ed4df1d59"
//   },
//   {
//     name: "AERENGA ARORANGI",
//     map: "COK-001-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "1b498318-1ccb-48fa-be16-58a80af3bd56"
//   },
//   {
//     name: "AERENGAMATE",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AERODROME RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "e289b9bc-23e1-45b1-ac4e-ce3694832b99"
//   },
//   {
//     name: "AERORA",
//     map: "COK-001-006-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "adf62d2f-ec70-4d6f-9e1f-3ac27e08208e"
//   },
//   {
//     name: "AFAAHITI, TAHITI",
//     map: null,
//     facilityCode: null,
//     country: "PYF",
//     intlTown: "AFAAHITI",
//     id: null
//   },
//   {
//     name: "AFEGA, SAMOA",
//     map: null,
//     facilityCode: null,
//     country: "WSM",
//     intlTown: "AFEGA",
//     id: null
//   },
//   {
//     name: "AGRICULTURE LABOURER",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AGRICULTURE STOREMAN",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AIPAE",
//     map: "COK-002-001-007",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "f724a24b-358a-4a3a-9fd1-31949bbc1433"
//   },
//   {
//     name: "AIRPORT",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AIRPORT AITUTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AISTRALIA",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "AITU",
//     map: "COK-002-001-008",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "a62ccf47-36b0-482a-98de-04894c9b1258"
//   },
//   {
//     name: "AITUAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUATAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUATKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAK",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKI (DECEASED)",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKI AITUTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKI ARUTANGA",
//     map: "COK-002-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0e0cf3cd-778d-4e61-aa9c-7545b50c5ac2"
//   },
//   {
//     name: "AITUTAKI COOK ISLAND",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKI COOK ISLANDS",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKI COOK ISLANS",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKI RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "e289b9bc-23e1-45b1-ac4e-ce3694832b99"
//   },
//   {
//     name: "AITUTAKI, COOK ISLANDER",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKI, COOK ISLANDS",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTAKU",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUTKAI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUYAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AITUYTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AIU",
//     map: "COK-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "c258d8fd-50b4-4295-99e6-baf1a794db14"
//   },
//   {
//     name: "AIUTAKI",
//     map: "COK-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0b8654b1-36d7-4e07-8a15-81321310a4a4"
//   },
//   {
//     name: "AKAIAMI  TAUTU AITUTAKI",
//     map: "COK-002-001-005",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "0d757a12-ba03-4f1e-8817-587b78903672"
//   },
//   {
//     name: "AKAOA",
//     map: "COK-001-005-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "b51022f2-e796-4334-86ee-43defa22ecd3"
//   },
//   {
//     name: "AKAOA ARORANGI",
//     map: "COK-001-005-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "b51022f2-e796-4334-86ee-43defa22ecd3"
//   },
//   {
//     name: "AKAOA ARORANGI RAROTONGA",
//     map: "COK-001-005-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "b51022f2-e796-4334-86ee-43defa22ecd3"
//   },
//   {
//     name: "AKAOA, ARORANGI, RAROTONGA",
//     map: "COK-001-005-003",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "b51022f2-e796-4334-86ee-43defa22ecd3"
//   },
//   {
//     name: "AKIRKBY DENMARK",
//     map: null,
//     facilityCode: null,
//     country: "DNK",
//     intlTown: "AKIRKBY",
//     id: null
//   },
//   {
//     name: "AKIRKEBY, DENMARK",
//     map: null,
//     facilityCode: null,
//     country: "DNK",
//     intlTown: "AKIRKEBY",
//     id: null
//   },
//   {
//     name: "AKUVAINE RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "e289b9bc-23e1-45b1-ac4e-ce3694832b99"
//   },
//   {
//     name: "ALGERIA AFRICA",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "ALGERIA, AFRICA",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "ALMERE, NEDERLANDSE",
//     map: null,
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: null
//   },
//   {
//     name: "ALOFI NIUE",
//     map: null,
//     facilityCode: null,
//     country: "NIU",
//     intlTown: "ALOFI",
//     id: null
//   },
//   {
//     name: "ALOFI, NIUE",
//     map: null,
//     facilityCode: null,
//     country: "NIU",
//     intlTown: "ALOFI",
//     id: null
//   },
//   {
//     name: "ALOGI NIUE",
//     map: null,
//     facilityCode: null,
//     country: "NIU",
//     intlTown: "ALOGI",
//     id: null
//   },
//   {
//     name: "AMANAIA",
//     map: "COK-006",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "d49d39c8-a544-440a-95ff-1500274726f5"
//   },
//   {
//     name: "AMANAIA PUKAPUKA",
//     map: "COK-011",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "4effa0c9-6e48-4cb9-92a0-72646e9acff7"
//   },
//   {
//     name: "AMANIA PUKAPUKA",
//     map: "COK-011",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "4effa0c9-6e48-4cb9-92a0-72646e9acff7"
//   },
//   {
//     name: "AMBULANCE EN ROUTE TO HOSPITAL, RAROTONGA",
//     map: "COK-011-001-002",
//     facilityCode: null,
//     country: null,
//     intlTown: null,
//     id: "e289b9bc-23e1-45b1-ac4e-ce3694832b99"
//   },
//   ... 4532 more items
// ]

// %% [markdown]
// ### Get all potential resolvers
// Use only resolvers for used event fields to avoid nulls

// %%
import { birthResolver, birthMetaData } from './mappings/birthResolver.ts'
import { transform } from './helpers/transform.ts'
import { bulkImport } from '../v1-to-v2-data-migration/helpers/gqlHandlers.ts'
import {
  batch,
  getIndexErrors,
} from '../v1-to-v2-data-migration/helpers/utils.ts'
import { generateRegistrationNumber } from './helpers/generators.ts'
import { CrvsEvent } from './helpers/types.ts'
import { BirthResolver } from './helpers/birthTypes.ts'
import { toCrvsDate } from './helpers/resolverHelpers.ts'
import {nameChangeResolver} from './mappings/nameChangeResolver.ts'

function nonNullObjectKeys(obj: Record<string, any>) {
  return Object.fromEntries(
    Object.entries(obj).filter(
      ([_, value]) => value !== null && value !== undefined && value !== '',
    ),
  )
}

const events: Array<CrvsEvent> = []

csvData.birth.forEach((birth) => {
  const declaration: Partial<Record<keyof typeof birthResolver, any>> = {}
  Object.entries(birthResolver).forEach(([eventField, dataField]) => {
    if (typeof dataField === 'function') {
      const data = dataField(birth, csvData, updatedLocationsMap)
      declaration[eventField as keyof typeof birthResolver] = data
    }
  })

  const meta: Partial<Record<keyof typeof birthMetaData, any>> = {}
  Object.entries(birthMetaData).forEach(([metaField, dataField]) => {
    const data = dataField(birth, csvData, updatedLocationsMap)
    meta[metaField as keyof typeof birthMetaData] = data
  })

  const user = 'f686c526-c6b5-41ed-b3cc-43b104fa5c03'
  //const location = '08260e22-bb67-4702-8760-86ec125e1079'
  const role = 'REGISTRAR' // Probably ok to hardcode this

  const locationId = locationCodes.find(
    (loc: any) => loc.code === meta.locationCode,
  )?.id

  const event = transform(
    nonNullObjectKeys(declaration),
    'birth',
    meta.registrationDate || new Date().toISOString(),
    user, //TODO change to lookup meta.registrar,
    role,
    locationId,
    birth.BIRTH_REF,
    birth.BIRTH_REF,
    // generateRegistrationNumber(
    //   meta.locationCode || '',
    //   meta.registrationDate || new Date().toISOString(),
    //   'birth',
    // ),
  )

  events.push(event)

  const nameChanges = csvData.deedpoll
    .filter(
      (deed) => deed.BIRTH_REF.toUpperCase() === birth.BIRTH_REF.toUpperCase(),
    )
    .sort(
      (a, b) =>
        new Date(toCrvsDate(a.DATE)).getTime() -
        new Date(toCrvsDate(b.DATE)).getTime(),
    )
  if (nameChanges.length > 0) {
    const nameChangeDeclaration = {}
    nameChanges.forEach((nc) => {
      Object.entries(nameChangeResolver).forEach(([eventField, dataField]) => {
        if (dataField) {
          const data = dataField(nc, birth, nameChanges)
          nameChangeDeclaration[eventField] = data
        }
      })
    })
    console.log(JSON.stringify(nameChangeDeclaration, null, 2))
  }
})

// const batches = batch(events, 1000)

// for (const batch of [batches[0]]) {
//   const res = await bulkImport(batch, sysToken)
//   console.log(res)
//   const errors = getIndexErrors(res)
//   if (errors) {
//     console.error('Errors during bulk import', errors)
//   }
// }
// Out:
// {
//   "subjects.name": "TEAURAKI",
//   "subjects.dob": "10/22/1933",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TEARAKI",
//   "newName.name.surname": "DANIEL",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MAATA",
//   "subjects.dob": "3/25/1936",
//   "subjects.address": "aitutaki",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "martha",
//   "newName.name.surname": "",
//   "witness.name": "marie haupini",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "TUTAI",
//   "subjects.dob": "5/1/1936",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TUTAI TOM",
//   "newName.name.surname": "-",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "ACT DR",
//   "witness.address": "TITIKAVEKA"
// }
// {
//   "subjects.name": "KITIMIRA-CAMERON",
//   "subjects.dob": "8/30/1937",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TUTAI KITIMIRA CAMERON",
//   "newName.name.surname": "MALIETOA TANUMAFILI II",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TANIE STRICKLAND",
//   "subjects.dob": "9/17/1939",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "DANCY TANIE",
//   "newName.name.surname": "STRICKLAND KAVANA",
//   "witness.name": "B TEARIKI",
//   "witness.occupation": "DR",
//   "witness.address": "AUCKLAND"
// }
// {
//   "subjects.name": "NELE",
//   "subjects.dob": "11/17/1939",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "NELLY NELE",
//   "newName.name.surname": "MAIRARO PI",
//   "witness.name": "T MAEA",
//   "witness.occupation": "DR",
//   "witness.address": "AITUTAKI"
// }
// {
//   "subjects.name": "FRANCIS DROLET",
//   "subjects.dob": "11/12/1940",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "PENEATA DROLLET",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVATIU"
// }
// {
//   "subjects.name": "RICHARD",
//   "subjects.dob": "11/30/1942",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "DAVEY",
//   "witness.name": "M HENRY",
//   "witness.occupation": "ACT DR",
//   "witness.address": "AITUTAKI"
// }
// {
//   "subjects.name": "EDDIE E.DOLLIER",
//   "subjects.dob": "12/18/1944",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "EDDIE DOLLIER",
//   "newName.name.surname": "TOM",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "IRAI MAEU TE RANGI",
//   "subjects.dob": "1/14/1945",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "JOSEPH BELOTTE",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TERE AKAAU ALBERT HENRY",
//   "subjects.dob": "11/28/1946",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TERE",
//   "newName.name.surname": "HENRY",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "IESE",
//   "subjects.dob": "11/20/1947",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "JESSE IESE",
//   "newName.name.surname": "",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TUARA TIKAKA",
//   "subjects.dob": "6/28/1953",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TUARA",
//   "newName.name.surname": "",
//   "witness.name": "TEATI MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TAKO II",
//   "subjects.dob": "5/19/1955",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "NOOROA DAVID",
//   "newName.name.surname": "TAKO",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "KAUKURA",
//   "subjects.dob": "6/24/1955",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ROBERT KAUKURA",
//   "newName.name.surname": "STRICKLAND",
//   "witness.name": "R NGATOA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AUCKLAND"
// }
// {
//   "subjects.name": "RUTA",
//   "subjects.dob": "4/25/1956",
//   "subjects.address": "aitutaki",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ruta roi",
//   "newName.name.surname": "",
//   "witness.name": "miri paniora",
//   "witness.occupation": "registration officer",
//   "witness.address": "auckland new zealand"
// }
// {
//   "subjects.name": "PUTOKO",
//   "subjects.dob": "9/24/1961",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "CHRISTIAN NAME: \"PUTOKO BEN\"",
//   "newName.name.surname": "SURNAME: \"MATAITI\" D.P. NO: 57/06",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TIMI",
//   "subjects.dob": "5/28/1964",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "SHAR",
//   "newName.name.surname": "EUAI",
//   "witness.name": "T YALA",
//   "witness.occupation": "CHIEL ADMIN OFFICER",
//   "witness.address": "WELLINGTON"
// }
// {
//   "subjects.name": "TAMANGARO",
//   "subjects.dob": "2/19/1965",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MICHAEL TAMANGARO JUNIOR",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ELENI",
//   "subjects.dob": "12/11/1974",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ELENI JULIET",
//   "newName.name.surname": "",
//   "witness.name": "TEATI MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ANGELO",
//   "subjects.dob": "3/10/1976",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "T'ANGELO",
//   "newName.name.surname": "TUNUPOPO",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVATIU"
// }
// {
//   "subjects.name": "TIPE GILE",
//   "subjects.dob": "12/2/1980",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "GILE TIPE",
//   "newName.name.surname": "-",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "NGATAE",
//   "subjects.dob": "4/19/1981",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "MATAPAKIA",
//   "witness.name": "T VAINEPOTO",
//   "witness.occupation": "DR",
//   "witness.address": "ATIU"
// }
// {
//   "subjects.name": "TEREAPII KAU MAPU",
//   "subjects.dob": "7/17/1981",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "SURNAME: \"EZEKIELA\"  D.P. NO:77/06  08.08.06",
//   "witness.name": "TIANA KOTEKA",
//   "witness.occupation": "STUDENT",
//   "witness.address": "AUCKLAND NEW ZEALAND"
// }
// {
//   "subjects.name": "INAU",
//   "subjects.dob": "8/8/1982",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "HINAU",
//   "newName.name.surname": "MONGA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TAMAROA",
//   "subjects.dob": "8/23/1984",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "POTINI",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVATIU"
// }
// {
//   "subjects.name": "RATAI JOTZ",
//   "subjects.dob": "2/9/1985",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "RATAI JAZZ",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "RUARANGI MATANGARO",
//   "subjects.dob": "2/3/1987",
//   "subjects.address": "Aitutaki",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Ruarangi",
//   "newName.name.surname": "",
//   "witness.name": "Nooapii Tearea",
//   "witness.occupation": "Registrar",
//   "witness.address": "Avarua"
// }
// {
//   "subjects.name": "BANABA",
//   "subjects.dob": "6/11/1988",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "BARNABAS TETAURA",
//   "newName.name.surname": "",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "IRANGI",
//   "subjects.dob": "4/6/1995",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "MAURI",
//   "witness.name": "TMATENGA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "TITIKAVEKA"
// }
// {
//   "subjects.name": "MATERUA",
//   "subjects.dob": "10/23/1995",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MATERUA BRIAN",
//   "newName.name.surname": "",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TUPAPAA",
//   "subjects.dob": "2/24/1999",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "CHRISTIAN NAME: \"BELLMA\" D.P. NO: 04/06",
//   "newName.name.surname": "",
//   "witness.name": "T MAEA",
//   "witness.occupation": "DR",
//   "witness.address": "ARUTANGA"
// }
// {
//   "subjects.name": "MAARA NGATOKORUA",
//   "subjects.dob": "9/6/2003",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "NGATOKORUA MIIMETUA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "PURUANIO TAMATOA",
//   "subjects.dob": "4/17/2005",
//   "subjects.address": "AITUTAKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "PURUANIO RICHMOND TAMATOA",
//   "newName.name.surname": "",
//   "witness.name": "T MAEA",
//   "witness.occupation": "DR",
//   "witness.address": "AITUTAKI"
// }
// {
//   "subjects.name": "MEMORY TEUMERE KAOKAO",
//   "subjects.dob": "11/11/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "subjects.nameChange1.deedPollNumber": "64/07",
//   "subjects.nameChange1.firstname": "TEREHANA",
//   "subjects.nameChange1.surname": "",
//   "newName.name.firstname": "TEREHANA",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TANGATA KOKOIA ETE TURIIA",
//   "subjects.dob": "2/2/1939",
//   "subjects.address": "Atiu",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Panu",
//   "newName.name.surname": "Toa",
//   "witness.name": "Teremoana Yala",
//   "witness.occupation": "Chief Administrative Officer",
//   "witness.address": "High commission, Wellington, New Zealand"
// }
// {
//   "subjects.name": "NGAMATA NGARO",
//   "subjects.dob": "12/29/1939",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "DOSITEA NGAMATA",
//   "newName.name.surname": "",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "RAROTONGA"
// }
// {
//   "subjects.name": "MATAPUTA",
//   "subjects.dob": "11/20/1940",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "ENGU TAVAI",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVATIU"
// }
// {
//   "subjects.name": "VAINE TAAKA-MAIA",
//   "subjects.dob": "6/2/1946",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "GEORGE",
//   "witness.name": "t mokoroa",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "NASINU COLLEGE NANDY AIR PORT",
//   "subjects.dob": "5/21/1951",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "NANDI",
//   "newName.name.surname": "TUAINE GLASSIE",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "NOOROA",
//   "subjects.dob": "12/27/1962",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "ANTHONY",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TANGATA TUTAI",
//   "subjects.dob": "11/5/1964",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TUTAI SABRINA",
//   "newName.name.surname": "",
//   "witness.name": "MR BLASHKI",
//   "witness.occupation": "RETIRED",
//   "witness.address": "27 HOPE STREET 10139, SPRINGVALE 3171, AUSTRALIA"
// }
// {
//   "subjects.name": "APAITOA",
//   "subjects.dob": "4/23/1966",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TOA",
//   "newName.name.surname": "TUKURANGI",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MIIMETUA",
//   "subjects.dob": "1/5/1969",
//   "subjects.address": "atiu",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "ewen john cameron",
//   "witness.name": "m haupini",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "TUTAI",
//   "subjects.dob": "1/20/1971",
//   "subjects.address": "atiu",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "ewen john cameron",
//   "witness.name": "m haupini",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "TANGI JIMMY",
//   "subjects.dob": "1/8/1973",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TANGI JIM JUNIOR",
//   "newName.name.surname": "TANGI JIM",
//   "witness.name": "T VAINEPOTO",
//   "witness.occupation": "DR",
//   "witness.address": "ATIU"
// }
// {
//   "subjects.name": "PELA",
//   "subjects.dob": "9/3/1978",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "BELLA",
//   "newName.name.surname": "",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MEMORY VAINE POMANI",
//   "subjects.dob": "3/9/1984",
//   "subjects.address": "ATIU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "PARE-KATUKE",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "",
//   "subjects.dob": "",
//   "subjects.address": "",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "",
//   "witness.name": "",
//   "witness.occupation": "",
//   "witness.address": ""
// }
// {
//   "subjects.name": "TOMOKINO TORU",
//   "subjects.dob": "9/28/1934",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "SOLOMONA",
//   "witness.name": "M TUAMINGI",
//   "witness.occupation": "DR",
//   "witness.address": "MANGAIA"
// }
// {
//   "subjects.name": "NGATEINA",
//   "subjects.dob": "8/15/1936",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "NGATEINA",
//   "newName.name.surname": "TAPENA MARETA RIA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TUAPIKEPIKE",
//   "subjects.dob": "12/29/1939",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "CHRISTIAN NAME:\"TUTU\"",
//   "newName.name.surname": "SURNAME:\"REEA\"",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ELMOND MEAUMATAORA",
//   "subjects.dob": "11/18/1946",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ELMOND IRIEA MEAUMATAORA KATAINA",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TOKOA",
//   "subjects.dob": "12/15/1952",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TOKOA MARIA",
//   "newName.name.surname": "",
//   "witness.name": "T KAOKAO",
//   "witness.occupation": "DR",
//   "witness.address": "MAUKE"
// }
// {
//   "subjects.name": "NEKEARE O TEREORA",
//   "subjects.dob": "2/25/1953",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TERESA NEKEARE O TEREORA",
//   "newName.name.surname": "KARENA",
//   "witness.name": "W WIKI",
//   "witness.occupation": "JP",
//   "witness.address": "AUCKLAND NZ"
// }
// {
//   "subjects.name": "OPETETANGI OTO MATOU MANA",
//   "subjects.dob": "10/31/1955",
//   "subjects.address": "mangaia",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "opetetangi pena",
//   "newName.name.surname": "",
//   "witness.name": "n maoate",
//   "witness.occupation": "act dr",
//   "witness.address": "rarotonga"
// }
// {
//   "subjects.name": "AEA KOE TE OA E AERE EI TE AREMAKI",
//   "subjects.dob": "1/24/1955",
//   "subjects.address": "Mangaia",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Teoa",
//   "newName.name.surname": "Aria",
//   "witness.name": "W Teariki",
//   "witness.occupation": "Consul General",
//   "witness.address": "Auckland"
// }
// {
//   "subjects.name": "PAUPAUARE",
//   "subjects.dob": "4/24/1958",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "PAUPAUARE PAULA",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "RAROTONGA"
// }
// {
//   "subjects.name": "NGATAMARIKI TEREMOANA",
//   "subjects.dob": "2/4/1961",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "NGATAMARIKI METUAUTI",
//   "newName.name.surname": "MAKITAE",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "ACT DR",
//   "witness.address": "TITIKAVEKA"
// }
// {
//   "subjects.name": "NOOTAURA",
//   "subjects.dob": "5/31/1962",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "AKARANA",
//   "newName.name.surname": "TUAPUTA ENOKA",
//   "witness.name": "W TEARIKI",
//   "witness.occupation": "CONSUL GENERAL",
//   "witness.address": "AUCKLAND NZ"
// }
// {
//   "subjects.name": "ARUMETUA",
//   "subjects.dob": "5/30/1962",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "NGAI PAREITI",
//   "witness.name": "M TUAMINGI",
//   "witness.occupation": "DR",
//   "witness.address": "MANGAIA"
// }
// {
//   "subjects.name": "MAARAMETUA",
//   "subjects.dob": "11/16/1962",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MAARAMETUA MOEAURI TUREPU",
//   "newName.name.surname": "BROWN",
//   "witness.name": "TMOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MUMMY",
//   "subjects.dob": "12/31/1963",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MARIA",
//   "newName.name.surname": "MIRIA TUAPUTA",
//   "witness.name": "R JOYCE",
//   "witness.occupation": "GSM JP",
//   "witness.address": "PAPAKURA NZ"
// }
// {
//   "subjects.name": "MAUAUA",
//   "subjects.dob": "1/17/1969",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "KIMI",
//   "newName.name.surname": "",
//   "witness.name": "N MAOATE",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "VOLLEY",
//   "subjects.dob": "4/21/1970",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MATA",
//   "newName.name.surname": "SOLOMONA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TE AU TAMARIKI TERE AERE",
//   "subjects.dob": "5/16/1970",
//   "subjects.address": "mangaia",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "teri",
//   "newName.name.surname": "daniel",
//   "witness.name": "t mokoroa",
//   "witness.occupation": "deputy registrar",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "BEVERLY",
//   "subjects.dob": "8/21/1972",
//   "subjects.address": "Mangaia",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "Akaiti",
//   "witness.name": "Tutai  Matenga",
//   "witness.occupation": "Acting Deputy Registrar",
//   "witness.address": "Rarotonga"
// }
// {
//   "subjects.name": "MIIMETUA",
//   "subjects.dob": "8/13/1974",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "AUSTIN MIIMETUA",
//   "newName.name.surname": "-",
//   "witness.name": "NOOROA TEAREA",
//   "witness.occupation": "REGISTRAR OF BIRTHS",
//   "witness.address": "RAROTONGA, COOK ISLANDS"
// }
// {
//   "subjects.name": "ABSALOM",
//   "subjects.dob": "5/16/1984",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "LAZARO",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "RAROTONGA"
// }
// {
//   "subjects.name": "POROAITI",
//   "subjects.dob": "2/5/1988",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "AMATAITI",
//   "witness.name": "M TUAMINGI",
//   "witness.occupation": "DR",
//   "witness.address": "MANGAIA"
// }
// {
//   "subjects.name": "HASEEN TEREMATAORA-KI-TONGAREVA",
//   "subjects.dob": "12/22/1994",
//   "subjects.address": "MANGAIA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ACHSIN TEREMATAORA KI TONGAREVA",
//   "newName.name.surname": "",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ELIET TANGIMETUA LORETTA JALOMINE",
//   "subjects.dob": "7/17/2006",
//   "subjects.address": "mangaia",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "eliet jalomine",
//   "newName.name.surname": "",
//   "witness.name": "t matenga",
//   "witness.occupation": "act dr",
//   "witness.address": "titikaveka"
// }
// {
//   "subjects.name": "TUTERU",
//   "subjects.dob": "6/14/1940",
//   "subjects.address": "MANIHIKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TIAKI",
//   "newName.name.surname": "TIARUA",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEMU ISAIA",
//   "subjects.dob": "1/14/1944",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "TOKA PIHO POMARE",
//   "witness.name": "TMATENGA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "TITIKAVEKA"
// }
// {
//   "subjects.name": "REPOAMA",
//   "subjects.dob": "9/5/1949",
//   "subjects.address": "MANIHIKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "ARAIPU",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVATIU"
// }
// {
//   "subjects.name": "PUA APII",
//   "subjects.dob": "3/14/1951",
//   "subjects.address": "MANIHIKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MATTHEW",
//   "newName.name.surname": "JOHNSON",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEPORA",
//   "subjects.dob": "4/11/1954",
//   "subjects.address": "manihiki",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "deborah",
//   "newName.name.surname": "",
//   "witness.name": "m haupini",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "ARAIPU HOA",
//   "subjects.dob": "5/26/1955",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ARAIPU HOA - TAIMAI",
//   "newName.name.surname": "BEN",
//   "witness.name": "NGATUAINE MAOATE",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "TUPAPA"
// }
// {
//   "subjects.name": "NGAMETUA",
//   "subjects.dob": "8/25/1957",
//   "subjects.address": "MANIHIKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TERESA ROIMATA",
//   "newName.name.surname": "BENEDITO",
//   "witness.name": "R NGATOA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AUCKLAND"
// }
// {
//   "subjects.name": "VAIATATORU TE KURAPO",
//   "subjects.dob": "11/12/1960",
//   "subjects.address": "MANIHIKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TEKURAPO BOBBIE",
//   "newName.name.surname": "KORONUI",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TERE",
//   "subjects.dob": "7/30/1963",
//   "subjects.address": "manihiki",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "mary tere tapeka",
//   "newName.name.surname": "manuel-fortes",
//   "witness.name": "t mokoroa",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "TEOKOTAI-O-TIHAU NAPARA",
//   "subjects.dob": "4/2/1977",
//   "subjects.address": "manihiki",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "kauraka tangaroa",
//   "witness.name": "m haupini",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "BENNY CHRISTOPHER",
//   "subjects.dob": "12/21/1985",
//   "subjects.address": "MANIHIKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "BENJAMIN",
//   "newName.name.surname": "TUTERU",
//   "witness.name": "TMOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "KIMIORA",
//   "subjects.dob": "12/15/1987",
//   "subjects.address": "MANIHIKI",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ANNE-THERESA KIMIORA",
//   "newName.name.surname": "TIHAU-NEHEMIA NAPARA",
//   "witness.name": "BII TEARIKI",
//   "witness.occupation": "DR",
//   "witness.address": "AUCKLAND NZ"
// }
// {
//   "subjects.name": "PAPA TARAEKA NGATUPUNA",
//   "subjects.dob": "10/7/1991",
//   "subjects.address": "manihiki",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "papa taraeka denis ngatupuna",
//   "newName.name.surname": "tihau-nehemia napara",
//   "witness.name": "w teariki",
//   "witness.occupation": "dr",
//   "witness.address": "auckland nz"
// }
// {
//   "subjects.name": "TUAKANA - PANU",
//   "subjects.dob": "2/7/1947",
//   "subjects.address": "mauke",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "linus panu",
//   "newName.name.surname": "williams",
//   "witness.name": "paul teatai ariki",
//   "witness.occupation": "porirua wellington nz",
//   "witness.address": "duty manager"
// }
// {
//   "subjects.name": "ROURUKEU",
//   "subjects.dob": "9/13/1951",
//   "subjects.address": "MAUKE",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ROURUKEU CAECILIA SUZY",
//   "newName.name.surname": "TAUU O TE RANGI WILLIAM-NAKUAPE",
//   "witness.name": "SHEILA SUMMERS",
//   "witness.occupation": "RETIRED TEACHER",
//   "witness.address": "AUCKLAND NEW ZEALAND"
// }
// {
//   "subjects.name": "METUANGARO",
//   "subjects.dob": "12/19/1959",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "subjects.nameChange1.deedPollNumber": "6/07",
//   "subjects.nameChange1.firstname": "",
//   "subjects.nameChange1.surname": "NGAMETUA",
//   "newName.name.firstname": "",
//   "newName.name.surname": "NGAMETUA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TUATOPA IA E TE POAKI",
//   "subjects.dob": "3/17/1960",
//   "subjects.address": "Mauke",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Teretina Tuatopaiaetepoaki",
//   "newName.name.surname": "Oaariki",
//   "witness.name": "TMokoroa",
//   "witness.occupation": "DR",
//   "witness.address": "Avarua"
// }
// {
//   "subjects.name": "RIMARII",
//   "subjects.dob": "10/4/1966",
//   "subjects.address": "Mauke",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Rimaru",
//   "newName.name.surname": "",
//   "witness.name": "",
//   "witness.occupation": "Justice of the Peace",
//   "witness.address": "Dandenong, Australia"
// }
// {
//   "subjects.name": "MAARA METUA",
//   "subjects.dob": "4/7/1970",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MARIA",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "NGAROKURA",
//   "subjects.dob": "5/30/1972",
//   "subjects.address": "mauke",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "matapuku",
//   "witness.name": "m haupini",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "TUPUNA KIMIORA KITE ENUAMAMAO",
//   "subjects.dob": "6/29/1979",
//   "subjects.address": "MAUKE",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "CATHERINE TUPUNA KIMIORA",
//   "newName.name.surname": "EDWIN",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEOKOTAI",
//   "subjects.dob": "12/10/1980",
//   "subjects.address": "MAUKE",
//   "subjects.nameChangedViaDeadPoll": true,
//   "subjects.nameChange1.deedPollNumber": "4/06",
//   "subjects.nameChange1.firstname": "TEOKOTAI IMMACULATA",
//   "subjects.nameChange1.surname": "",
//   "newName.name.firstname": "GEORGI - MAGDALENE IMMACULATA TEOKOTAI",
//   "newName.name.surname": "",
//   "witness.name": "M. HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "METUAVAINE",
//   "subjects.dob": "7/3/1993",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "METUAVAINE BENEDICTA",
//   "newName.name.surname": "",
//   "witness.name": "TEATI MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "VAINE NOO POTI",
//   "subjects.dob": "7/26/1936",
//   "subjects.address": "MITIARO",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MATILDA ROURU",
//   "newName.name.surname": "",
//   "witness.name": "W TEARIKI",
//   "witness.occupation": "CONSUL GENERAL",
//   "witness.address": "AUCKLAND NZ"
// }
// {
//   "subjects.name": "TANGATA TUA VERAVERA I TE RA",
//   "subjects.dob": "1/15/1949",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TUA VERAVERA",
//   "newName.name.surname": "RUI IORANGI",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TURI",
//   "subjects.dob": "1/10/1954",
//   "subjects.address": "mitiaro",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "taruia",
//   "witness.name": "m haupini",
//   "witness.occupation": "dr",
//   "witness.address": "avatiu"
// }
// {
//   "subjects.name": "VAINE",
//   "subjects.dob": "3/11/1967",
//   "subjects.address": "MITIARO",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TANGI VAINE",
//   "newName.name.surname": "NGATUAINE",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEAUMETUA",
//   "subjects.dob": "11/10/1968",
//   "subjects.address": "MITIARO",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "CHRISTIAN NAME: \"MATAIAPO TEAUMETUA\" D.P.NO.8/2006",
//   "newName.name.surname": "",
//   "witness.name": "NOOAPII TEAREA",
//   "witness.occupation": "REGISTRAR",
//   "witness.address": "NIKAO"
// }
// {
//   "subjects.name": "MAARA METUA",
//   "subjects.dob": "8/4/1970",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "TOPA",
//   "witness.name": "G NAYAR",
//   "witness.occupation": "POLICE OFFICER",
//   "witness.address": "AUSTRALIA"
// }
// {
//   "subjects.name": "MATAPUTA",
//   "subjects.dob": "11/9/1971",
//   "subjects.address": "MITIARO",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "SID MATA",
//   "newName.name.surname": "-",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TUAKERE",
//   "subjects.dob": "11/18/1971",
//   "subjects.address": "MITIARO",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "TAPUTOA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MAARA METUA-O-NGAIORAE",
//   "subjects.dob": "6/29/1983",
//   "subjects.address": "MITIARO",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "NGATOKO",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": ""
// }
// {
//   "subjects.name": "PATRICIA MEMORY",
//   "subjects.dob": "10/1/2000",
//   "subjects.address": "MITIARO",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "PATRICIA MEMORY FATI",
//   "newName.name.surname": "",
//   "witness.name": "JULIAN AUPUNI",
//   "witness.occupation": "JP",
//   "witness.address": "MITIARO"
// }
// {
//   "subjects.name": "RAUKELE",
//   "subjects.dob": "5/5/1987",
//   "subjects.address": "NASSAU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "RAUKERE",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "EDWARD",
//   "subjects.dob": "4/14/1957",
//   "subjects.address": "Palmerston",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Christian Name: \"Edward William\"",
//   "newName.name.surname": "Surname: \"Marsters\" D.P.No.9/2006",
//   "witness.name": "Teati Mokoroa",
//   "witness.occupation": "D/R",
//   "witness.address": "Avarua"
// }
// {
//   "subjects.name": "TAMARIKI",
//   "subjects.dob": "12/26/1965",
//   "subjects.address": "PALMERSTON",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TIA MARAMA TAUARIKI",
//   "newName.name.surname": "ANGENE BROWN",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "D.R.",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "JOHN",
//   "subjects.dob": "7/10/1992",
//   "subjects.address": "palmerston island",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "john dick",
//   "newName.name.surname": "",
//   "witness.name": "t matenga",
//   "witness.occupation": "acting deputy registrar",
//   "witness.address": "rarotonga"
// }
// {
//   "subjects.name": "ROO",
//   "subjects.dob": "5/27/1920",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ROO JOHN",
//   "newName.name.surname": "TAI",
//   "witness.name": "TEATI MOKOROA",
//   "witness.occupation": "DP",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MUNOKOA",
//   "subjects.dob": "11/21/1938",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MATETORU MUNOKOA",
//   "newName.name.surname": "PURUA TATA TAUTU",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEIMANU",
//   "subjects.dob": "6/2/1940",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "SEIMANU MATA ARIKISELE",
//   "newName.name.surname": "-",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TAUNGAMAKI",
//   "subjects.dob": "4/22/1942",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "SAUNGAKI SONNY",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "RAROTONGA"
// }
// {
//   "subjects.name": "MURISEI",
//   "subjects.dob": "12/20/1944",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MIRINOA MURISEI",
//   "newName.name.surname": "FORD",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEOKOTAI NAPOROAKI",
//   "subjects.dob": "7/26/1948",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TEOKOTAI NAPOROAKI WILLIE",
//   "newName.name.surname": "",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "ACTING DR",
//   "witness.address": "TITIKAVEKA"
// }
// {
//   "subjects.name": "TINONUI",
//   "subjects.dob": "6/16/1952",
//   "subjects.address": "OMOKA PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TINONUI RAMAARIKI MAKIRAU",
//   "newName.name.surname": "ISAIA",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "SALVICTOR",
//   "subjects.dob": "1/17/1957",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "MARTIN TAKAU KARIKA D.P. NO:79/06   16.08.06",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "KURAITI",
//   "subjects.dob": "11/24/1958",
//   "subjects.address": "penrhyn",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "kuraiti teata louise",
//   "newName.name.surname": "singapu",
//   "witness.name": "taire marsters",
//   "witness.occupation": "nsw australia",
//   "witness.address": "jp"
// }
// {
//   "subjects.name": "TATAHIRANGI MAHUTA",
//   "subjects.dob": "10/31/1963",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "TINI WILLIAMS",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TARAKAIMANO TUTAPU TUARAU",
//   "subjects.dob": "7/5/1964",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TARAKAIMANO TUARAU",
//   "newName.name.surname": "-",
//   "witness.name": "B TEARIKI",
//   "witness.occupation": "CONSUL GENERAL- DR",
//   "witness.address": "AUCKLAND NEW ZEALAND"
// }
// {
//   "subjects.name": "POKO",
//   "subjects.dob": "1/17/1967",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "JOHN WILLIAMS",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "RAUPENAPENA",
//   "subjects.dob": "12/6/1969",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "HENRY RAUPENAPENA",
//   "newName.name.surname": "-",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "SAMUEL DICK FORD",
//   "subjects.dob": "1/6/1977",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "WILLIAM FORD",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TATAHIRANGI MAHUTA OFFICER INCHARGE",
//   "subjects.dob": "3/19/1985",
//   "subjects.address": "PENRHYN",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "WILLIAMS",
//   "witness.name": "T HAGAN",
//   "witness.occupation": "REG GEN",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ETUATI",
//   "subjects.dob": "3/19/1944",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "SURNAME: \"APERA\" D.P. NO:38/6  27.03.06",
//   "witness.name": "WILLIAM TEARIKI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "127 SYMONDS STREET AUCKLAND"
// }
// {
//   "subjects.name": "ALETIO",
//   "subjects.dob": "6/4/1944",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "PIIRA",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEARAIKA",
//   "subjects.dob": "2/7/1948",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "HAGAI",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "YENGARO",
//   "subjects.dob": "12/29/1955",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "HENRY-TAI TURIA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ANGAANGA",
//   "subjects.dob": "5/26/1956",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "MATAORA",
//   "witness.name": "TEREMOANA YALA",
//   "witness.occupation": "CHIEF ADMIN",
//   "witness.address": "WELLINGTON NZ"
// }
// {
//   "subjects.name": "NAORA",
//   "subjects.dob": "7/8/1958",
//   "subjects.address": "NASSAU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "MARUKORE",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "KUPUYEYE",
//   "subjects.dob": "4/27/1959",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "KUPUYEYE TEPANO",
//   "newName.name.surname": "TAUIA",
//   "witness.name": "R NGATOA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AUCKLAND"
// }
// {
//   "subjects.name": "TENUKULOA",
//   "subjects.dob": "3/23/1960",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "NUKU ROTI",
//   "newName.name.surname": "RAPANA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ROROPI",
//   "subjects.dob": "5/24/1960",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TEROROPI",
//   "newName.name.surname": "",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MARY",
//   "subjects.dob": "8/22/1965",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MARY",
//   "newName.name.surname": "TIMOTI",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "WAURA",
//   "subjects.dob": "7/27/1977",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "VERONICA WAULA",
//   "newName.name.surname": "",
//   "witness.name": "N MAOATE",
//   "witness.occupation": "ACT DR",
//   "witness.address": "RAROTONGA"
// }
// {
//   "subjects.name": "HENE",
//   "subjects.dob": "8/3/1978",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "HENRY",
//   "newName.name.surname": "",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ABELA",
//   "subjects.dob": "2/5/1980",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ABELA TAUPA",
//   "newName.name.surname": "RAVARUA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEKIPA",
//   "subjects.dob": "6/3/1981",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "KUPA",
//   "witness.name": "T YALA",
//   "witness.occupation": "CHIEF ADMIN OFFICER",
//   "witness.address": "WELLINGTON, C/- COOK ISLANDS HIGH COM"
// }
// {
//   "subjects.name": "NGARIMA TAUNGA",
//   "subjects.dob": "1/11/1983",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "REMER",
//   "newName.name.surname": "MARUKORE",
//   "witness.name": "R NGATOA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AUCKLAND"
// }
// {
//   "subjects.name": "MAKATIA JUNIOR",
//   "subjects.dob": "1/9/1991",
//   "subjects.address": "NASSAU",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "TUAINEKORE",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "AKURIKO",
//   "subjects.dob": "7/14/1996",
//   "subjects.address": "PUKAPUKA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "TITONGA HENRY",
//   "witness.name": "",
//   "witness.occupation": "DR",
//   "witness.address": "ROTO PUKAPUKA"
// }
// {
//   "subjects.name": "TETUA",
//   "subjects.dob": "10/4/1939",
//   "subjects.address": "RAKAHANGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MII ANNIE LAURIE TETUA",
//   "newName.name.surname": "RAHITI",
//   "witness.name": "B TEARIKI",
//   "witness.occupation": "CONSULATE GENERAL",
//   "witness.address": "AUCKLAND NZ"
// }
// {
//   "subjects.name": "RIKI BOYS BRIGADE PICNIC",
//   "subjects.dob": "1/15/1959",
//   "subjects.address": "RAKAHANGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "RIKI",
//   "newName.name.surname": "KAIRUA",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "KAUKURA",
//   "subjects.dob": "2/23/1971",
//   "subjects.address": "RAKAHANGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "TUAINE",
//   "witness.name": "TMOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "VAIMATA",
//   "subjects.dob": "5/1/1921",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "RANGIETUROA AKEAU TERANGITAVIVO",
//   "newName.name.surname": "TEARII VAATAU MAVE",
//   "witness.name": "",
//   "witness.occupation": "",
//   "witness.address": ""
// }
// {
//   "subjects.name": "TAEA TEARIKI TARAARE",
//   "subjects.dob": "12/24/1928",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "TAEA",
//   "witness.name": "DEAN MARSTERS",
//   "witness.occupation": "JUSTICE OF THE PEACE",
//   "witness.address": "NEW ZEALAND"
// }
// {
//   "subjects.name": "VELMA BROWN",
// ...
//   "newName.name.firstname": "",
//   "newName.name.surname": "PUNATAU MATAIO",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "HAILEY RANGI MOANA THADAR",
//   "subjects.dob": "1/23/2004",
//   "subjects.address": "Rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Hailey Kyi Thadar",
//   "newName.name.surname": "",
//   "witness.name": "Marie Haupini",
//   "witness.occupation": "Deputy Registrar",
//   "witness.address": "Avarua"
// }
// {
//   "subjects.name": "RAYMOND IRIEA - THOMAS",
//   "subjects.dob": "4/4/2004",
//   "subjects.address": "Rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Teremoana-Nui-O-Kiva Iriea Raymond",
//   "newName.name.surname": "",
//   "witness.name": "M Haupini",
//   "witness.occupation": "DR",
//   "witness.address": "Avatiu"
// }
// {
//   "subjects.name": "ROMATT PRECIOUS MEMORY",
//   "subjects.dob": "9/10/2004",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ROMATT PRECIOUS MEMORY GABRIEL",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "CONSTANTINE ARTEINA PETISA",
//   "subjects.dob": "11/29/2004",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "CONSTANCE ARTEINA PETISA",
//   "newName.name.surname": "",
//   "witness.name": "TEATI MOKOROA",
//   "witness.occupation": "D/R",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "CORONA",
//   "subjects.dob": "12/6/2004",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "CORONER",
//   "newName.name.surname": "RUBENA RUARAU",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TE - URURENGA MELVIN JAMES",
//   "subjects.dob": "4/2/2005",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "VEIAO",
//   "witness.name": "TMATENGA",
//   "witness.occupation": "ASS. DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEMARUMANARII MICHAEL JOEFANO",
//   "subjects.dob": "7/27/2005",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "SURNAME: \"TUTAI\"  D.P. NO:72/06  05.07.06",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "KAY KAUVAI COMMODORE",
//   "subjects.dob": "8/19/2005",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TIARE KAY KAUVAI COMMODORE",
//   "newName.name.surname": "",
//   "witness.name": "NGATUAINE MAOATE",
//   "witness.occupation": "ACTING DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MIA POERAVA",
//   "subjects.dob": "8/19/2005",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "MATAPUKU-SIMONSEN",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "ACT DR",
//   "witness.address": "TITIKAVEKA"
// }
// {
//   "subjects.name": "NGATOKOA",
//   "subjects.dob": "9/14/2005",
//   "subjects.address": "rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ngatokoa antony william",
//   "newName.name.surname": "",
//   "witness.name": "m haupini",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "PIRI RAYWINN",
//   "subjects.dob": "9/30/2005",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "PIRI KAELIM",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVATIU"
// }
// {
//   "subjects.name": "VIOLET VAIETU LANGI TELINA",
//   "subjects.dob": "12/20/2005",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TELINA VAIETU LANGI VIOLET",
//   "newName.name.surname": "JOSEPH",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVATIU"
// }
// {
//   "subjects.name": "VAINE ARII-E-RAA VAITUMA II ABERAHAMA NOOANA",
//   "subjects.dob": "1/2/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "vaine arii-e-raa vaituma II aberahama napot nooana",
//   "newName.name.surname": "-",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "ACT DR",
//   "witness.address": "TITIKAVEKA"
// }
// {
//   "subjects.name": "JUNIOR MAKA TEMARANGI RICHARD PARE JUMILE",
//   "subjects.dob": "1/15/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "MAKA TEMARANGI RICHARD PARE BROWNE JUMILE",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "SETEFANO ALANZO TIMOE-A-TAHERE TUMUPU KEA MARSTERS",
//   "subjects.dob": "1/4/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "SETEPHANO ALANZO TIMOE - A - TAHERE TUMUPU KEA MARSTERS",
//   "newName.name.surname": "",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEAVA WHITNEY PEARSE",
//   "subjects.dob": "1/28/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "GEORGE",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEOKOTAI BASETEHEPA",
//   "subjects.dob": "3/5/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "BASETEHEPA TEOKOTAI",
//   "newName.name.surname": "-",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "PETERINA ELIZABETH NGATOKOTORU",
//   "subjects.dob": "5/15/2006",
//   "subjects.address": "rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "koputai peterina elizabeth ngatokotoru",
//   "newName.name.surname": "",
//   "witness.name": "t maea & t matenga",
//   "witness.occupation": "dr & acting dr",
//   "witness.address": "aitutaki & rarotonga"
// }
// {
//   "subjects.name": "BARTIMAEUS TIMA TUAINEOKOTAI",
//   "subjects.dob": "6/24/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "BARTIMAEUS TIMA TUAINEOKOTAI",
//   "newName.name.surname": "TUAINEOKOTAI",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "RAERA ENUA",
//   "subjects.dob": "8/28/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "RAERA I TE TOKA TARAVA",
//   "newName.name.surname": "VEIAO",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTRY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "KAYLA MAIRE",
//   "subjects.dob": "8/23/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "KAYLA-MARAMA",
//   "newName.name.surname": "",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "JUSTICE",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "DOMINIC MIIMETUA",
//   "subjects.dob": "10/4/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "DOMINIQUE MIIMETUA",
//   "newName.name.surname": "",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "ASSISTANT DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "LESLEY JAMES",
//   "subjects.dob": "10/6/2006",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "LESLEY TUTANGATA",
//   "newName.name.surname": "",
//   "witness.name": "MHAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MOE ARAI TAMAAKO",
//   "subjects.dob": "10/20/2006",
//   "subjects.address": "rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "james moe",
//   "newName.name.surname": "nganu",
//   "witness.name": "t tupa",
//   "witness.occupation": "jp",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "PAORA NUI MAKA KEA NGATOKOTORU",
//   "subjects.dob": "12/19/2006",
//   "subjects.address": "rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "paora nui mataio kea ngatokotoru",
//   "newName.name.surname": "",
//   "witness.name": "t mokoroa",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "DANCY TAPITA MEMORY",
//   "subjects.dob": "1/25/2007",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "IRITI MARIA DANCY TAPITA MEMORY",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "JOSEPH BOY",
//   "subjects.dob": "3/12/2007",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "HERMAN-JONASSEN",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MEMORY KIMLYN CHRISTIANA",
//   "subjects.dob": "5/1/2007",
//   "subjects.address": "rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "kimlyn christiana",
//   "newName.name.surname": "",
//   "witness.name": "t matenga",
//   "witness.occupation": "act dr",
//   "witness.address": "titikaveka"
// }
// {
//   "subjects.name": "DEODORA GINA TUNUI",
//   "subjects.dob": "5/9/2007",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ALONE KIMIORA",
//   "newName.name.surname": "",
//   "witness.name": "MHAUPINI",
//   "witness.occupation": "DEPUTRY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ROGER JUNIOR",
//   "subjects.dob": "6/5/2007",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "TAUAREA ROBATI",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "METUANGARO ETHAN",
//   "subjects.dob": "7/30/2007",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "ETHAN A MAKEA TINIRAU VAITOTI",
//   "newName.name.surname": "",
//   "witness.name": "TMOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "AVA-ROSE ASANYA FEIA",
//   "subjects.dob": "8/9/2007",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "-",
//   "newName.name.surname": "KEREOPA",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "JETHRO PAERANGI TATUAVA",
//   "subjects.dob": "9/10/2007",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "JETHRO PAERANGI",
//   "newName.name.surname": "TATUAVA-TARIPO",
//   "witness.name": "T MATENGA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "IFRAAN ZEDRICK-NUMANGA",
//   "subjects.dob": "11/3/2007",
//   "subjects.address": "Rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "Zedrick-Numanga",
//   "newName.name.surname": "-",
//   "witness.name": "Tutai Matnega",
//   "witness.occupation": "Acting Deputy Registrar",
//   "witness.address": "Rarotonga"
// }
// {
//   "subjects.name": "MEMORY MUMBO",
//   "subjects.dob": "2/2/2008",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "CHRISTIAN NAME: \"MEMORY MUMBO VAINE\"",
//   "newName.name.surname": "",
//   "witness.name": "TUTAI MATENGA",
//   "witness.occupation": "ACTING DEPUTY REGISTRAR",
//   "witness.address": "RAROTONGA"
// }
// {
//   "subjects.name": "PORAVINA",
//   "subjects.dob": "2/22/2008",
//   "subjects.address": "rarotonga",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "pora-a-teaupo",
//   "newName.name.surname": "",
//   "witness.name": "mhaupini",
//   "witness.occupation": "dr",
//   "witness.address": "avarua"
// }
// {
//   "subjects.name": "ATHENA ANNETTE",
//   "subjects.dob": "2/12/2009",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "NAPA-NICHOLAS",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTRY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "ELECTRA-DENISE-OURANIA ENGARA",
//   "subjects.dob": "3/1/2009",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "PAUKA",
//   "witness.name": "TMOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "DAISY SARA",
//   "subjects.dob": "3/10/2009",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "BANIANI",
//   "witness.name": "TMOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "MANURERE",
//   "subjects.dob": "3/29/2009",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TAKURIA",
//   "newName.name.surname": "PATAKU",
//   "witness.name": "TMOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "JIMMY ELI",
//   "subjects.dob": "3/27/2009",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "RUSSELL-ATAI",
//   "witness.name": "TMATENGA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "TITIKAVEKA"
// }
// {
//   "subjects.name": "TUAKANA",
//   "subjects.dob": "3/28/2009",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TUAKANA",
//   "newName.name.surname": "TUAINEOKOTAI",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "TEMATA-MATAI",
//   "subjects.dob": "6/2/2009",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "TEMATA-MATAI EMMETT",
//   "newName.name.surname": "",
//   "witness.name": "M HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "CIDARRAN ZEPHANIAH MALAKAI NOEL",
//   "subjects.dob": "6/6/2009",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "",
//   "newName.name.surname": "VAETORU-MILES",
//   "witness.name": "T MOKOROA",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "AVARUA"
// }
// {
//   "subjects.name": "JUSTINE RUITA CLEMENCE",
//   "subjects.dob": "6/11/2001",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "JUSTINE CLEMENCE",
//   "newName.name.surname": "",
//   "witness.name": "VAINE TANGATAPOTO",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "ATIU"
// }
// {
//   "subjects.name": "KAHN DOMINIC",
//   "subjects.dob": "11/24/2005",
//   "subjects.address": "RAROTONGA",
//   "subjects.nameChangedViaDeadPoll": true,
//   "newName.name.firstname": "KAHN DOMINIC ARAITI",
//   "newName.name.surname": "BURROWS-REUTHER",
//   "witness.name": "MARIE HAUPINI",
//   "witness.occupation": "DEPUTY REGISTRAR",
//   "witness.address": "RAROTONGA, COOK ISLANDS"
// }

// %%
import { reindex } from "../v1-to-v2-data-migration/helpers/gqlHandlers.ts";

const reindexResponse = await reindex(sysToken);
reindexResponse
// Out:
// "OK"

// %% [markdown]
// ### Output results

// %%
console.log('🍞 Declarations succesfully migrated')
// Out:
// 🍞 Declarations succesfully migrated
